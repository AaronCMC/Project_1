# %% [markdown]
# # Dependencies

# %%
# DEPENDENCIES
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # CSV to DFs
# (load csv paths & read csv to DFs)

# %%
# BROAD
Mental_Disorders = Path("Resources/Mental health Depression disorder Data.csv")
Mental_Disorders_OGdf = pd.read_csv(Mental_Disorders, delimiter=',')
Gender_Depression_OGdf = pd.read_csv(Mental_Disorders, delimiter=',', header = 6469)
Suicide_rate_OGdf = pd.read_csv(Mental_Disorders, delimiter = ',', header = 54277)

GDP_HealthExp = Path("Resources/World_Bank/HealthExpGDP%.csv")
GDP_HealthExp_OGdf = pd.read_csv(GDP_HealthExp, delimiter=',')

GDP = Path("Resources/World_Bank/GDP_USD.csv")
GDP_OGdf = pd.read_csv(GDP, delimiter = ',')

Pop = Path("Resources/World_Bank/Pop.csv")
Pop_OGdf = pd.read_csv(Pop, delimiter = ',')

Urban_Pop = Path("Resources/World_Bank/Urban_Pop.csv")
Urban_Pop_OGdf = pd.read_csv(Urban_Pop, delimiter = ',')

Pop_Density = Path("Resources/World_Bank/Pop_density.csv")
Pop_Density_OGdf = pd.read_csv(Pop_Density, delimiter = ',')

Undernourishment = Path("Resources/World_Bank/Undernourishment%.csv")
Undernourishment_OGdf = pd.read_csv(Undernourishment, delimiter=',')

Life_Exp = Path("Resources/World_Bank/Life_Exp.csv")
Life_Exp_OGdf = pd.read_csv(Life_Exp, delimiter = ',')

Unemployment = Path("Resources/World_Bank/Unemployment.csv")
Unemployment_OGdf = pd.read_csv(Unemployment, delimiter = ',')

Age_Dep_Ratio = Path("Resources/World_Bank/Age_Dep_Ratio.csv")
Age_Dep_Ratio_OGdf = pd.read_csv(Age_Dep_Ratio, delimiter = ',')

Air_Poll = Path("Resources/World_Bank/Air_Poll.csv")
Air_Poll_OGdf = pd.read_csv(Air_Poll, delimiter = ',')

# NARROW
Gini = Path("Resources/World_Bank/Gini.csv")
Gini_OGdf = pd.read_csv(Gini, delimiter=',')

#Mental_Health = Path("Resources/Mental Health Dataset.csv")
#Mental_Health_df = pd.read_csv(Mental_Health)

#World_Bank = Path("Resources/2.12_Health_systems.csv")
#World_Bank_df = pd.read_csv(World_Bank)
# Out:
# /var/folders/m6/bhhzzj012vq18r_pf4rv2l640000gn/T/ipykernel_6230/2901924725.py:3: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   Mental_Disorders_OGdf = pd.read_csv(Mental_Disorders, delimiter=',')
# /var/folders/m6/bhhzzj012vq18r_pf4rv2l640000gn/T/ipykernel_6230/2901924725.py:4: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   Gender_Depression_OGdf = pd.read_csv(Mental_Disorders, delimiter=',', header = 6469)

# %% [markdown]
# # Prep DFs for Merge
# (column renames, dropna values, iloc rows, melts, column formatting)

# %%
# BROAD DFs
Mental_Disorders_df_torename = Mental_Disorders_OGdf.drop('index', axis=1)
Mental_Disorders_df_torowdrop = Mental_Disorders_df_torename.rename(columns={"Entity": "Country Name", "Code": "Country Code"})
Mental_Disorders_df_todropna = Mental_Disorders_df_torowdrop.iloc[0:6468]
Mental_Disorders_df = Mental_Disorders_df_todropna.dropna()
Mental_Disorders_df

Gender_Depression_df_toiloc = Gender_Depression_OGdf[['Entity', 'Code', 'Year', 'Prevalence in males (%)', 'Prevalence in females (%)']]
Gender_Depression_df_torename = Gender_Depression_df_toiloc.iloc[0:47807]
Gender_Depression_df_todropna = Gender_Depression_df_torename.rename(columns={"Entity": "Country Name", "Code": "Country Code"})
Gender_Depression_df_toformat = Gender_Depression_df_todropna.dropna()
#Gender_Depression_df_toformat["Prevalence in males (%)"] = Gender_Depression_df_toformat["Prevalence in males (%)"].map("{:.0f}".format)
#Gender_Depression_df_toformat["Prevalence in females (%)"] = Gender_Depression_df_toformat["Prevalence in females (%)"].map("{:.0f}".format)
Gender_Depression_df = Gender_Depression_df_toformat
Gender_Depression_df

Suicide_rate_df_torename = Suicide_rate_OGdf[['Entity', 'Code', 'Year', 'Suicide rate (deaths per 100,000 individuals)', 'Depressive disorder rates (number suffering per 100,000)']]
Suicide_rate_df_todropna = Suicide_rate_df_torename.rename(columns={"Entity": "Country Name", "Code": "Country Code"})
Suicide_rate_df = Suicide_rate_df_todropna.dropna()
Suicide_rate_df

GDP_HealthExp_df_tomelt = GDP_HealthExp_OGdf[["Country Name", "Country Code", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
GDP_HealthExp_df_todropna = GDP_HealthExp_df_tomelt.melt(id_vars=["Country Name", "Country Code"], var_name = "Year", value_name = "Percentage GDP Health Expenditure")
GDP_HealthExp_df = GDP_HealthExp_df_todropna.dropna()
GDP_HealthExp_df

GDP_df_tomelt = GDP_OGdf[["Country Name", "Country Code", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
GDP_df_todropna = GDP_df_tomelt.melt(id_vars=["Country Name", "Country Code"], var_name = "Year", value_name = "GDP (Current USD)")
GDP_df_toformat = GDP_df_todropna.dropna()
GDP_df_toformat["GDP (Current USD)"] = GDP_df_toformat["GDP (Current USD)"].map("{:.0f}".format)
#GDP_df_toformat.loc[:, "GDP (Current USD)"] = GDP_df_toformat["GDP (Current USD)"].map("{:.2f}".format)
GDP_df = GDP_df_toformat
GDP_df

Pop_df_tomelt = Pop_OGdf[["Country Name", "Country Code", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
Pop_df_todtopna = Pop_df_tomelt.melt(id_vars=["Country Name", "Country Code"], var_name = "Year", value_name = "Population")
Pop_df_toformat = Pop_df_todtopna.dropna()
Pop_df_toformat["Population"] = Pop_df_toformat["Population"].map("{:.0f}".format)
Pop_df = Pop_df_toformat
Pop_df

Urban_Pop_df_tomelt = Urban_Pop_OGdf[["Country Name", "Country Code", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
Urban_Pop_df_todropna = Urban_Pop_df_tomelt.melt(id_vars=["Country Name", "Country Code"], var_name = "Year", value_name = "Urban Population")
Urban_Pop_df_toformat = Urban_Pop_df_todropna.dropna()
Urban_Pop_df_toformat["Urban Population"] = Urban_Pop_df_toformat["Urban Population"].map("{:.0f}".format)
Urban_Pop_df = Urban_Pop_df_toformat
Urban_Pop_df

Pop_Density_df_tomelt = Pop_Density_OGdf[["Country Name", "Country Code", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
Pop_Density_df_todropna = Pop_Density_df_tomelt.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="Population Density")
Pop_Density_df_toformat = Pop_Density_df_todropna.dropna()
Pop_Density_df_toformat["Population Density"] = Pop_Density_df_toformat["Population Density"].map("{:.0f}".format)
Pop_Density_df = Pop_Density_df_toformat
Pop_Density_df

Undernourishment_df_tomelt = Undernourishment_OGdf[["Country Name", "Country Code", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
Undernourishment_df_todtopna = Undernourishment_df_tomelt.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="Undernourishment (%)")
Undernourishment_df = Undernourishment_df_todtopna.dropna()
Undernourishment_df

Life_Exp_df_tomelt = Life_Exp_OGdf[["Country Name", "Country Code", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
Life_Exp_df_todropna = Life_Exp_df_tomelt.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="Life Expectancy")
Life_Exp_df_toformat = Life_Exp_df_todropna.dropna()
Life_Exp_df_toformat["Life Expectancy"] = Life_Exp_df_toformat["Life Expectancy"].map("{:.0f}".format)
Life_Exp_df = Life_Exp_df_toformat
Life_Exp_df

Unemployment_df_tomelt = Unemployment_OGdf[["Country Name", "Country Code", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
Unemployment_df_todtopna = Unemployment_df_tomelt.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="Unemployment (%)")
Unemployment_df = Unemployment_df_todtopna.dropna()
Unemployment_df

Age_Dep_Ratio_df_tomelt = Age_Dep_Ratio_OGdf[["Country Name", "Country Code", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
Age_Dep_Ratio_df_todtopna = Age_Dep_Ratio_df_tomelt.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="Age Dependency Ratio (%)")
Age_Dep_Ratio_df = Age_Dep_Ratio_df_todtopna.dropna()
Age_Dep_Ratio_df

Air_Poll_df_tomelt = Air_Poll_OGdf[["Country Name", "Country Code", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
Air_Poll_df_todtopna = Air_Poll_df_tomelt.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="PM2.5 Air Pollution")
Air_Poll_df_toformat = Air_Poll_df_todtopna.dropna()
Air_Poll_df_toformat["PM2.5 Air Pollution"] = Air_Poll_df_toformat["PM2.5 Air Pollution"].map("{:.2f}".format)
Air_Poll_df = Air_Poll_df_toformat
Air_Poll_df


# NARROW DFs
Gini_df_tomelt = Gini_OGdf[["Country Name", "Country Code", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]]
Gini_df_todtopna = Gini_df_tomelt.melt(id_vars=["Country Name", "Country Code"], var_name="Year", value_name="Gini Index")
Gini_df = Gini_df_todtopna.dropna()
Gini_df
# Out:
# /var/folders/m6/bhhzzj012vq18r_pf4rv2l640000gn/T/ipykernel_6230/3023035308.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GDP_df_toformat["GDP (Current USD)"] = GDP_df_toformat["GDP (Current USD)"].map("{:.0f}".format)
# /var/folders/m6/bhhzzj012vq18r_pf4rv2l640000gn/T/ipykernel_6230/3023035308.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Pop_df_toformat["Population"] = Pop_df_toformat["Population"].map("{:.0f}".format)
# /var/folders/m6/bhhzzj012vq18r_pf4rv2l640000gn/T/ipykernel_6230/3023035308.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Urban_Pop_df_toformat["Urban Population"] = Urban_Pop_df_toformat["Urban Population"].map("{:.0f}".format)
# /var/folders/m6/bhhzzj012vq18r_pf4rv2l640000gn/T/ipykernel_6230/3023035308.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Pop_Density_df_toformat["Population Density"] = Pop_Density_df_toformat["Population Density"].map("{:.0f}".format)
# /var/folders/m6/bhhzzj012vq18r_pf4rv2l640000gn/T/ipykernel_6230/3023035308.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Life_Exp_df_toformat["Life Expectancy"] = Life_Exp_df_toformat["Life Expectancy"].map("{:.0f}".format)
# /var/folders/m6/bhhzzj012vq18r_pf4rv2l640000gn/T/ipykernel_6230/3023035308.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Air_Poll_df_toformat["PM2.5 Air Pollution"] = Air_Poll_df_toformat["PM2.5 Air Pollution"].map("{:.2f}".format)
#        Country Name Country Code  Year  Gini Index
# 9         Argentina          ARG  2010        43.7
# 10          Armenia          ARM  2010        30.0
# 13        Australia          AUS  2010        34.7
# 14          Austria          AUT  2010        30.3
# 17          Belgium          BEL  2010        28.4
# ...             ...          ...   ...         ...
# 2110        Ukraine          UKR  2017        26.0
# 2112        Uruguay          URY  2017        39.5
# 2113  United States          USA  2017        41.2
# 2123         Kosovo          XKX  2017        29.0
# 2127       Zimbabwe          ZWE  2017        44.3
#
# [647 rows x 4 columns]

# %% [markdown]
# # Merge
# on = ['Country Name', 'Country Code', 'Year'], how = 'inner'

# %%
# MERGING
HealthExp_Disorders_df = pd.merge(GDP_HealthExp_df, Mental_Disorders_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
GDP_HealthExp_Disorders_df = pd.merge(GDP_df, HealthExp_Disorders_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
GDP_HealthExp_Disorders_Gender_df = pd.merge(GDP_HealthExp_Disorders_df, Gender_Depression_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
GDP_HealthExp_Disorders_UN_df = pd.merge(GDP_HealthExp_Disorders_Gender_df, Undernourishment_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
GDP_HealthExp_Disorders_UNemp_df = pd.merge(GDP_HealthExp_Disorders_UN_df, Unemployment_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
GDP_HealthExp_Disorders_UNemp_AgeDep_df = pd.merge(GDP_HealthExp_Disorders_UNemp_df, Age_Dep_Ratio_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
GDP_HealthExp_Disorders_Pop_df = pd.merge(GDP_HealthExp_Disorders_UNemp_AgeDep_df, Pop_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
GDP_HealthExp_Disorders_PopUrb_df= pd.merge(GDP_HealthExp_Disorders_Pop_df, Urban_Pop_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
GDP_HealthExp_Disorders_Pops_df = pd.merge(GDP_HealthExp_Disorders_PopUrb_df, Pop_Density_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
GDP_HealthExp_Disorders_Pops_AirP_df = pd.merge(GDP_HealthExp_Disorders_Pops_df, Air_Poll_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
#GDP_HealthExp_Disorders_Pops_Gini_df = pd.merge(GDP_HealthExp_Disorders_Pops_df, Gini_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
GDP_HealthExp_Disorders_Pops_le_df = pd.merge(GDP_HealthExp_Disorders_Pops_AirP_df, Life_Exp_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')
GDP_HealthExp_Disorders_Pops_Suicide_df = pd.merge(GDP_HealthExp_Disorders_Pops_le_df, Suicide_rate_df, on = ['Country Name', 'Country Code', 'Year'], how = 'inner')

Macro_Disorder_df = GDP_HealthExp_Disorders_Pops_Suicide_df.copy()
Macro_Disorder_df
# Out:
#               Country Name Country Code  Year GDP (Current USD)  \
# 0              Afghanistan          AFG  2010       15856668556
# 1                   Angola          AGO  2010       83799474070
# 2                  Albania          ALB  2010       11926926616
# 3     United Arab Emirates          ARE  2010      300189052689
# 4                Argentina          ARG  2010      423627422092
# ...                    ...          ...   ...               ...
# 1105               Vanuatu          VUT  2017         880061834
# 1106                 Samoa          WSM  2017         884844384
# 1107          South Africa          ZAF  2017      381448814653
# 1108                Zambia          ZMB  2017       25873601261
# 1109              Zimbabwe          ZWE  2017       17584890937
#
#       Percentage GDP Health Expenditure Schizophrenia (%)  \
# 0                              8.569672           0.16513
# 1                              2.695100          0.170158
# 2                              6.236677          0.199308
# 3                              3.878731          0.213138
# 4                              9.445464          0.197541
# ...                                 ...               ...
# 1105                           2.762855          0.214734
# 1106                           5.161202          0.234876
# 1107                           7.977112          0.181937
# 1108                           4.781562          0.165866
# 1109                           6.363583          0.157963
#
#      Bipolar disorder (%) Eating disorders (%)  Anxiety disorders (%)  \
# 0                0.705313             0.097327               4.862777
# 1                0.622503             0.156364               3.277828
# 2                0.703064             0.160337               3.391246
# 3                 0.80147             0.260129               4.200126
# 4                0.771084             0.381185               6.268718
# ...                   ...                  ...                    ...
# 1105             0.427419             0.106462               3.218816
# 1106             0.460366             0.126132               3.255973
# 1107             0.636613             0.214718               3.992830
# 1108             0.605972             0.142768               3.599714
# 1109             0.611242             0.124443               3.110926
#
#       Drug use disorders (%)  ...  Undernourishment (%)  Unemployment (%)  \
# 0                   2.571349  ...                  20.5             7.914
# 1                   0.503415  ...                  22.6            16.598
# 2                   0.500270  ...                   5.4            14.086
# 3                   3.059998  ...                   7.4             2.789
# 4                   0.955035  ...                   3.5             7.714
# ...                      ...  ...                   ...               ...
# 1105                0.698906  ...                  10.4             5.288
# 1106                0.844905  ...                   7.9             9.400
# 1107                0.921499  ...                   5.7            23.992
# 1108                0.515972  ...                  29.4             8.518
# 1109                0.772648  ...                  36.3             6.347
#
#      Age Dependency Ratio (%) Population  Urban Population  \
# 0                  105.433416   28189672           6691382
# 1                   93.586571   23364185          13967811
# 2                   48.352701    2913021           1519519
# 3                   16.172016    8481771           7132067
# 4                   56.625613   40788453          37055902
# ...                       ...        ...               ...
# 1105                77.051180     290239             73033
# 1106                75.551478     207630             38312
# 1107                52.261300   56641209          37298236
# 1108                87.051023   17298054           7434012
# 1109                83.101286   14751101           4755312
#
#       Population Density  PM2.5 Air Pollution Life Expectancy  \
# 0                     43                51.82              61
# 1                     19                28.63              57
# 2                    106                21.63              78
# 3                    119                43.53              78
# 4                     15                13.74              76
# ...                  ...                  ...             ...
# 1105                  24                12.89              70
# 1106                  75                10.90              73
# 1107                  47                28.86              65
# 1108                  23                26.18              62
# 1109                  38                22.58              61
#
#      Suicide rate (deaths per 100,000 individuals)  \
# 0                                         9.875393
# 1                                        13.177998
# 2                                         5.257754
# 3                                         5.149191
# 4                                        10.783922
# ...                                            ...
# 1105                                     17.699601
# 1106                                     10.001743
# 1107                                     11.150289
# 1108                                     13.060061
# 1109                                     26.391769
#
#      Depressive disorder rates (number suffering per 100,000)
# 0                                           4053.953769
# 1                                           4098.150892
# 2                                           2106.380192
# 3                                           2711.270791
# 4                                           3363.831257
# ...                                                 ...
# 1105                                        3069.681955
# 1106                                        2951.095793
# 1107                                        3613.578944
# 1108                                        3577.959846
# 1109                                        3094.795065
#
# [1110 rows x 24 columns]

# %%
## Merged DF Country Count
len(Macro_Disorder_df['Country Name'].unique())
# Out:
# 140

# %%
# CASTING in Merged DF
Macro_Disorder_df = Macro_Disorder_df.astype({"Population Density": float}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"Urban Population": float}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"Population": float}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"Eating disorders (%)": float}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"Bipolar disorder (%)": float}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"Schizophrenia (%)": float}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"GDP (Current USD)": float}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"Prevalence in males (%)": float}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"Prevalence in females (%)": float}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"Year": int}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"Suicide rate (deaths per 100,000 individuals)": float}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"Life Expectancy": float}, errors = 'raise')
Macro_Disorder_df = Macro_Disorder_df.astype({"PM2.5 Air Pollution": float}, errors = 'raise')

# %%
## Merged DF column dtypes
Macro_Disorder_df.dtypes
# Out:
# Country Name                                                 object
# Country Code                                                 object
# Year                                                          int64
# GDP (Current USD)                                           float64
# Percentage GDP Health Expenditure                           float64
# Schizophrenia (%)                                           float64
# Bipolar disorder (%)                                        float64
# Eating disorders (%)                                        float64
# Anxiety disorders (%)                                       float64
# Drug use disorders (%)                                      float64
# Depression (%)                                              float64
# Alcohol use disorders (%)                                   float64
# Prevalence in males (%)                                     float64
# Prevalence in females (%)                                   float64
# Undernourishment (%)                                        float64
# Unemployment (%)                                            float64
# Age Dependency Ratio (%)                                    float64
# Population                                                  float64
# Urban Population                                            float64
# Population Density                                          float64
# PM2.5 Air Pollution                                         float64
# Life Expectancy                                             float64
# Suicide rate (deaths per 100,000 individuals)               float64
# Depressive disorder rates (number suffering per 100,000)    float64
# dtype: object

# %%
## Merged DF columns
Macro_Disorder_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Year', 'GDP (Current USD)',
#        'Percentage GDP Health Expenditure', 'Schizophrenia (%)',
#        'Bipolar disorder (%)', 'Eating disorders (%)', 'Anxiety disorders (%)',
#        'Drug use disorders (%)', 'Depression (%)', 'Alcohol use disorders (%)',
#        'Prevalence in males (%)', 'Prevalence in females (%)',
#        'Undernourishment (%)', 'Unemployment (%)', 'Age Dependency Ratio (%)',
#        'Population', 'Urban Population', 'Population Density',
#        'PM2.5 Air Pollution', 'Life Expectancy',
#        'Suicide rate (deaths per 100,000 individuals)',
#        'Depressive disorder rates (number suffering per 100,000)'],
#       dtype='object')

# %% [markdown]
# # Create Extended Data Frame to perform column calculations
# (Macro_Disorder_df >>> Macro_Disorder_ext_df)

# %%
Macro_Disorder_ext_df = Macro_Disorder_df.copy()

# COLUMN CALCULATIONS
Macro_Disorder_ext_df['GDP per Capita (USD)'] = Macro_Disorder_ext_df['GDP (Current USD)'] / Macro_Disorder_ext_df['Population']
Macro_Disorder_ext_df['Health Expenditure (USD)'] = Macro_Disorder_ext_df['GDP (Current USD)'] * Macro_Disorder_ext_df['Percentage GDP Health Expenditure'] / 100

Macro_Disorder_ext_df['Schizophrenia (#)'] = Macro_Disorder_ext_df['Schizophrenia (%)'] * Macro_Disorder_ext_df['Population'] / 100
Macro_Disorder_ext_df['Bipolar disorder (#)'] = Macro_Disorder_ext_df['Bipolar disorder (%)'] * Macro_Disorder_ext_df['Population'] / 100
Macro_Disorder_ext_df['Eating disorders (#)'] = Macro_Disorder_ext_df['Eating disorders (%)'] * Macro_Disorder_ext_df['Population'] / 100
Macro_Disorder_ext_df['Anxiety disorders (#)'] = Macro_Disorder_ext_df['Anxiety disorders (%)'] * Macro_Disorder_ext_df['Population'] / 100
Macro_Disorder_ext_df['Drug use disorders (#)'] = Macro_Disorder_ext_df['Drug use disorders (%)'] * Macro_Disorder_ext_df['Population'] / 100
Macro_Disorder_ext_df['Depression (#)'] = Macro_Disorder_ext_df['Depression (%)'] * Macro_Disorder_ext_df['Population'] / 100
Macro_Disorder_ext_df['Alcohol use disorders (#)'] = Macro_Disorder_ext_df['Alcohol use disorders (%)'] * Macro_Disorder_ext_df['Population'] / 100

# %%
len(Macro_Disorder_ext_df.columns)
# Out:
# 33

# %%
Macro_Disorder_ext_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Year', 'GDP (Current USD)',
#        'Percentage GDP Health Expenditure', 'Schizophrenia (%)',
#        'Bipolar disorder (%)', 'Eating disorders (%)', 'Anxiety disorders (%)',
#        'Drug use disorders (%)', 'Depression (%)', 'Alcohol use disorders (%)',
#        'Prevalence in males (%)', 'Prevalence in females (%)',
#        'Undernourishment (%)', 'Unemployment (%)', 'Age Dependency Ratio (%)',
#        'Population', 'Urban Population', 'Population Density',
#        'PM2.5 Air Pollution', 'Life Expectancy',
#        'Suicide rate (deaths per 100,000 individuals)',
#        'Depressive disorder rates (number suffering per 100,000)',
#        'GDP per Capita (USD)', 'Health Expenditure (USD)', 'Schizophrenia (#)',
#        'Bipolar disorder (#)', 'Eating disorders (#)', 'Anxiety disorders (#)',
#        'Drug use disorders (#)', 'Depression (#)',
#        'Alcohol use disorders (#)'],
#       dtype='object')

# %% [markdown]
# ### Create CSV of Macro_Disorder_ext_df

# %%
Macro_Disorder_ext_df.to_csv("Output_Data/Macro_Disorder_ext.csv")

# %% [markdown]
# # Quick Anlayses

# %% [markdown]
# ### Sorted Mean Disorder Rates by Country

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Depression (%)", ascending=False)
# Out:
#                  Year  GDP (Current USD)  Percentage GDP Health Expenditure  \
# Country Name
# Lesotho        2013.5       2.360112e+09                           9.608697
# Morocco        2013.5       1.116601e+11                           5.255282
# Uganda         2013.5       2.946436e+10                           5.595820
# Finland        2013.5       2.575622e+11                           9.462500
# United States  2013.5       1.726294e+13                          16.338498
# ...               ...                ...                                ...
# Myanmar        2013.5       6.052697e+10                           3.695000
# Poland         2013.5       5.027401e+11                           6.438750
# Peru           2013.5       1.883263e+11                           4.812483
# Colombia       2013.5       3.304462e+11                           7.191757
# Albania        2013.5       1.242621e+10                           6.383303
#
#                Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# Lesotho                 0.159894              0.605449              0.131378
# Morocco                 0.185472              0.780434              0.168759
# Uganda                  0.159126              0.608530              0.115132
# Finland                 0.264402              1.004707              0.592246
# United States           0.335926              0.652297              0.525801
# ...                          ...                   ...                   ...
# Myanmar                 0.210185              0.508917              0.115698
# Poland                  0.206156              0.710718              0.220183
# Peru                    0.202113              0.890134              0.363514
# Colombia                0.205024              0.765992              0.246970
# Albania                 0.200223              0.703828              0.167811
#
#                Anxiety disorders (%)  Drug use disorders (%)  Depression (%)  \
# Country Name
# Lesotho                     3.474355                0.764170        5.623608
# Morocco                     4.983991                1.603445        5.579045
# Uganda                      3.501130                0.537489        5.052701
# Finland                     3.749232                0.912382        4.895461
# United States               6.667410                3.174581        4.786085
# ...                              ...                     ...             ...
# Myanmar                     3.302902                0.569866        2.273375
# Poland                      3.462014                0.802974        2.269322
# Peru                        4.259384                0.586798        2.266113
# Colombia                    2.517587                1.101227        2.205738
# Albania                     3.389137                0.509068        2.204248
#
#                Alcohol use disorders (%)  ...  \
# Country Name                              ...
# Lesotho                         1.671783  ...
# Morocco                         0.573709  ...
# Uganda                          1.290151  ...
# Finland                         2.742668  ...
# United States                   2.013025  ...
# ...                                  ...  ...
# Myanmar                         0.868910  ...
# Poland                          2.028608  ...
# Peru                            1.446616  ...
# Colombia                        1.756655  ...
# Albania                         1.845656  ...
#
#                Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# Lesotho                                              5489.031156
# Morocco                                              5360.326634
# Uganda                                               4989.112273
# Finland                                              4501.477184
# United States                                        4350.217810
# ...                                                          ...
# Myanmar                                              2217.194939
# Poland                                               2133.027893
# Peru                                                 2183.184205
# Colombia                                             2090.187567
# Albania                                              2103.936665
#
#                GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# Lesotho                 1130.719446              2.271020e+08
# Morocco                 3282.423581              5.864260e+09
# Uganda                   819.981795              1.635564e+09
# Finland                47326.228856              2.437974e+10
# United States          54348.025610              2.824040e+12
# ...                             ...                       ...
# Myanmar                 1189.372536              2.279380e+09
# Poland                 13223.256168              3.236588e+10
# Peru                    6210.258056              9.077679e+09
# Colombia                7116.062692              2.368822e+10
# Albania                 4297.338744              7.930106e+08
#
#                Schizophrenia (#)  Bipolar disorder (#)  Eating disorders (#)  \
# Country Name
# Lesotho             3.341672e+03          1.265212e+04          2.747022e+03
# Morocco             6.308796e+04          2.654430e+05          5.744043e+04
# Uganda              5.727838e+04          2.190046e+05          4.149830e+04
# Finland             1.439127e+04          5.469292e+04          3.224029e+04
# United States       1.065734e+06          2.069513e+06          1.667848e+06
# ...                          ...                   ...                   ...
# Myanmar             1.069000e+05          2.587872e+05          5.889389e+04
# Poland              7.837837e+04          2.702080e+05          8.370939e+04
# Peru                6.122092e+04          2.696027e+05          1.101335e+05
# Colombia            9.533079e+04          3.561324e+05          1.149089e+05
# Albania             5.789645e+03          2.035206e+04          4.851868e+03
#
#                Anxiety disorders (#)  Drug use disorders (#)  Depression (#)  \
# Country Name
# Lesotho                 7.260438e+04            1.597071e+04    1.175196e+05
# Morocco                 1.695122e+06            5.456081e+05    1.896555e+06
# Uganda                  1.260244e+06            1.934878e+05    1.815970e+06
# Finland                 2.040953e+05            4.967848e+04    2.664618e+05
# United States           2.115255e+07            1.008020e+07    1.518609e+07
# ...                              ...                     ...             ...
# Myanmar                 1.679552e+06            2.898087e+05    1.156132e+06
# Poland                  1.316225e+06            3.052859e+05    8.627784e+05
# Peru                    1.290068e+06            1.776930e+05    6.863800e+05
# Colombia                1.170378e+06            5.118341e+05    1.025328e+06
# Albania                 9.800170e+04            1.471962e+04    6.373856e+04
#
#                Alcohol use disorders (#)
# Country Name
# Lesotho                     3.493058e+04
# Morocco                     1.951372e+05
# Uganda                      4.643421e+05
# Finland                     1.492659e+05
# United States               6.387442e+06
# ...                                  ...
# Myanmar                     4.418418e+05
# Poland                      7.712544e+05
# Peru                        4.380509e+05
# Colombia                    8.167092e+05
# Albania                     5.336953e+04
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Drug use disorders (%)", ascending=False)
# Out:
#                           Year  GDP (Current USD)  \
# Country Name
# United States           2013.5       1.726294e+13
# United Arab Emirates    2013.5       3.737504e+11
# Afghanistan             2013.5       1.877711e+10
# Libya                   2010.5       6.177504e+10
# Canada                  2013.5       1.703144e+12
# ...                        ...                ...
# Chad                    2013.5       1.164383e+10
# Guinea                  2013.5       8.268321e+09
# Mali                    2013.5       1.327881e+10
# Bosnia and Herzegovina  2013.5       1.770410e+10
# Burkina Faso            2013.5       1.261384e+10
#
#                         Percentage GDP Health Expenditure  Schizophrenia (%)  \
# Country Name
# United States                                   16.338498           0.335926
# United Arab Emirates                             3.661436           0.212233
# Afghanistan                                      9.738543           0.165654
# Libya                                            3.649832           0.199054
# Canada                                          10.613959           0.314629
# ...                                                   ...                ...
# Chad                                             4.258966           0.167147
# Guinea                                           4.261464           0.165426
# Mali                                             4.056776           0.167067
# Bosnia and Herzegovina                           9.228750           0.200014
# Burkina Faso                                     5.271503           0.163591
#
#                         Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# United States                       0.652297              0.525801
# United Arab Emirates                0.803678              0.259951
# Afghanistan                         0.706685              0.102210
# Libya                               0.804959              0.247465
# Canada                              0.714746              0.473224
# ...                                      ...                   ...
# Chad                                0.625581              0.119013
# Guinea                              0.628627              0.108949
# Mali                                0.627895              0.114439
# Bosnia and Herzegovina              0.717259              0.167545
# Burkina Faso                        0.620595              0.109146
#
#                         Anxiety disorders (%)  Drug use disorders (%)  \
# Country Name
# United States                        6.667410                3.174581
# United Arab Emirates                 4.224241                3.007827
# Afghanistan                          4.871668                2.548328
# Libya                                4.965422                2.495451
# Canada                               5.168592                2.215271
# ...                                       ...                     ...
# Chad                                 2.881160                0.446516
# Guinea                               2.894611                0.443142
# Mali                                 2.882351                0.435812
# Bosnia and Herzegovina               3.401150                0.432951
# Burkina Faso                         2.892406                0.431673
#
#                         Depression (%)  Alcohol use disorders (%)  ...  \
# Country Name                                                       ...
# United States                 4.786085                   2.013025  ...
# United Arab Emirates          2.860571                   0.763392  ...
# Afghanistan                   4.133733                   0.662114  ...
# Libya                         3.783189                   0.687114  ...
# Canada                        3.939233                   1.602571  ...
# ...                                ...                        ...  ...
# Chad                          3.927036                   0.943801  ...
# Guinea                        3.546614                   0.940663  ...
# Mali                          2.958872                   0.903738  ...
# Bosnia and Herzegovina        2.331241                   2.844114  ...
# Burkina Faso                  3.631523                   0.993756  ...
#
#                         Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# United States                                                 4350.217810
# United Arab Emirates                                          2712.904069
# Afghanistan                                                   4048.679358
# Libya                                                         3598.269890
# Canada                                                        3587.189870
# ...                                                                   ...
# Chad                                                          3886.755881
# Guinea                                                        3512.411693
# Mali                                                          2928.852401
# Bosnia and Herzegovina                                        2221.257251
# Burkina Faso                                                  3607.242821
#
#                         GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# United States                   54348.025610              2.824040e+12
# United Arab Emirates            42512.109886              1.365521e+10
# Afghanistan                       588.247075              1.828026e+09
# Libya                            9697.749356              2.204455e+09
# Canada                          48386.464477              1.805056e+11
# ...                                      ...                       ...
# Chad                              872.730933              4.933345e+08
# Guinea                            734.047033              3.561172e+08
# Mali                              764.796096              5.363187e+08
# Bosnia and Herzegovina           4912.207424              1.633931e+09
# Burkina Faso                      703.453554              6.670823e+08
#
#                         Schizophrenia (#)  Bipolar disorder (#)  \
# Country Name
# United States                1.065734e+06          2.069513e+06
# United Arab Emirates         1.864559e+04          7.061544e+04
# Afghanistan                  5.305841e+04          2.263348e+05
# Libya                        1.262033e+04          5.103480e+04
# Canada                       1.108851e+05          2.518962e+05
# ...                                   ...                   ...
# Chad                         2.250796e+04          8.422535e+04
# Guinea                       1.856699e+04          7.054703e+04
# Mali                         2.898380e+04          1.089186e+05
# Bosnia and Herzegovina       7.215592e+03          2.587669e+04
# Burkina Faso                 2.934601e+04          1.113050e+05
#
#                         Eating disorders (#)  Anxiety disorders (#)  \
# Country Name
# United States                   1.667848e+06           2.115255e+07
# United Arab Emirates            2.284070e+04           3.711888e+05
# Afghanistan                     3.281274e+04           1.560283e+06
# Libya                           1.569006e+04           3.148073e+05
# Canada                          1.667907e+05           1.821542e+06
# ...                                      ...                    ...
# Chad                            1.604530e+04           3.879025e+05
# Guinea                          1.223847e+04           3.248468e+05
# Mali                            1.986759e+04           5.000012e+05
# Bosnia and Herzegovina          6.040447e+03           1.227063e+05
# Burkina Faso                    1.960606e+04           5.187620e+05
#
#                         Drug use disorders (#)  Depression (#)  \
# Country Name
# United States                     1.008020e+07    1.518609e+07
# United Arab Emirates              2.641824e+05    2.513438e+05
# Afghanistan                       8.153747e+05    1.323854e+06
# Libya                             1.581975e+05    2.398564e+05
# Canada                            7.809234e+05    1.388458e+06
# ...                                        ...             ...
# Chad                              6.017746e+04    5.283484e+05
# Guinea                            4.977394e+04    3.980402e+05
# Mali                              7.566744e+04    5.135581e+05
# Bosnia and Herzegovina            1.561910e+04    8.412097e+04
# Burkina Faso                      7.750166e+04    6.516642e+05
#
#                         Alcohol use disorders (#)
# Country Name
# United States                        6.387442e+06
# United Arab Emirates                 6.706449e+04
# Afghanistan                          2.120333e+05
# Libya                                4.356394e+04
# Canada                               5.648504e+05
# ...                                           ...
# Chad                                 1.270609e+05
# Guinea                               1.055805e+05
# Mali                                 1.567661e+05
# Bosnia and Herzegovina               1.026192e+05
# Burkina Faso                         1.782730e+05
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Alcohol use disorders (%)", ascending=False)
# Out:
#                 Year  GDP (Current USD)  Percentage GDP Health Expenditure  \
# Country Name
# Belarus       2013.5       6.224053e+10                           5.576250
# Estonia       2013.5       2.392430e+10                           6.418904
# Ukraine       2013.5       1.392018e+11                           7.207500
# Lithuania     2013.5       4.386123e+10                           6.438750
# Latvia        2013.5       2.837783e+10                           5.731250
# ...              ...                ...                                ...
# Malaysia      2013.5       3.063094e+11                           3.549732
# Morocco       2013.5       1.116601e+11                           5.255282
# Japan         2013.5       5.344169e+12                          10.461250
# Israel        2013.5       2.954080e+11                           7.002500
# Italy         2013.5       2.062186e+12                           8.798750
#
#               Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# Belarus                0.196351              0.698998              0.202387
# Estonia                0.202972              0.708207              0.250890
# Ukraine                0.190648              0.687080              0.170071
# Lithuania              0.198952              0.697681              0.223410
# Latvia                 0.198503              0.696002              0.219414
# ...                         ...                   ...                   ...
# Malaysia               0.250205              0.577872              0.193819
# Morocco                0.185472              0.780434              0.168759
# Japan                  0.301147              0.688160              0.458133
# Israel                 0.261428              0.923243              0.447987
# Italy                  0.236690              0.946427              0.622571
#
#               Anxiety disorders (%)  Drug use disorders (%)  Depression (%)  \
# Country Name
# Belarus                    2.946223                0.783977        4.055568
# Estonia                    2.965800                1.130113        3.921010
# Ukraine                    2.940969                0.687299        4.113148
# Lithuania                  2.928479                0.597525        4.174476
# Latvia                     2.944052                1.032556        3.496659
# ...                             ...                     ...             ...
# Malaysia                   4.425950                0.660110        3.437114
# Morocco                    4.983991                1.603445        5.579045
# Japan                      3.560696                0.898137        3.221601
# Israel                     3.073164                0.696951        3.968718
# Italy                      5.630789                1.261018        3.457573
#
#               Alcohol use disorders (%)  ...  \
# Country Name                             ...
# Belarus                        5.430544  ...
# Estonia                        4.907905  ...
# Ukraine                        4.875319  ...
# Lithuania                      4.509327  ...
# Latvia                         4.468094  ...
# ...                                 ...  ...
# Malaysia                       0.644127  ...
# Morocco                        0.573709  ...
# Japan                          0.573446  ...
# Israel                         0.508047  ...
# Italy                          0.466016  ...
#
#               Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# Belarus                                             3789.769589
# Estonia                                             3627.783437
# Ukraine                                             3872.668827
# Lithuania                                           3920.676568
# Latvia                                              3265.318154
# ...                                                         ...
# Malaysia                                            3220.315217
# Morocco                                             5360.326634
# Japan                                               2898.432240
# Israel                                              3690.675077
# Italy                                               3193.121550
#
#               GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# Belarus                6580.912826              3.456024e+09
# Estonia               18125.783662              1.535417e+09
# Ukraine                3063.806466              9.933557e+09
# Lithuania             14896.315198              2.818516e+09
# Latvia                14146.312614              1.623303e+09
# ...                            ...                       ...
# Malaysia              10087.406485              1.090496e+10
# Morocco                3282.423581              5.864260e+09
# Japan                 41927.215530              5.579178e+11
# Israel                36123.856385              2.071908e+10
# Italy                 34309.055811              1.814694e+11
#
#               Schizophrenia (#)  Bipolar disorder (#)  Eating disorders (#)  \
# Country Name
# Belarus            18573.132447          66119.489977          19144.012069
# Estonia             2679.890780           9350.750383           3312.552216
# Ukraine            86510.127162         311777.366400          77166.314469
# Lithuania           5869.234612          20584.565043           6586.137131
# Latvia              3988.913487          13987.193546           4407.339025
# ...                         ...                   ...                   ...
# Malaysia           75978.311798         175445.584043          58893.974475
# Morocco            63087.955964         265442.978764          57440.434010
# Japan             383761.047974         876923.688795         583806.243489
# Israel             21306.897974          75264.057226          36547.123136
# Italy             142342.712946         569175.312428         374420.131977
#
#               Anxiety disorders (#)  Drug use disorders (#)  Depression (#)  \
# Country Name
# Belarus                2.786886e+05            7.415768e+04    3.836244e+05
# Estonia                3.915879e+04            1.492127e+04    5.177364e+04
# Ukraine                1.334530e+06            3.118287e+05    1.866536e+06
# Lithuania              8.640363e+04            1.761591e+04    1.231899e+05
# Latvia                 5.916540e+04            2.074758e+04    7.027204e+04
# ...                             ...                     ...             ...
# Malaysia               1.343183e+06            2.004901e+05    1.043964e+06
# Morocco                1.695122e+06            5.456081e+05    1.896555e+06
# Japan                  4.537384e+06            1.144454e+06    4.105050e+06
# Israel                 2.505019e+05            5.685853e+04    3.232323e+05
# Italy                  3.386310e+06            7.580213e+05    2.079371e+06
#
#               Alcohol use disorders (#)
# Country Name
# Belarus                    5.136850e+05
# Estonia                    6.480549e+04
# Ukraine                    2.212605e+06
# Lithuania                  1.330814e+05
# Latvia                     8.980642e+04
# ...                                 ...
# Malaysia                   1.955574e+05
# Morocco                    1.951372e+05
# Japan                      7.307240e+05
# Israel                     4.139070e+04
# Italy                      2.802535e+05
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Anxiety disorders (%)", ascending=False)
# Out:
#                  Year  GDP (Current USD)  Percentage GDP Health Expenditure  \
# Country Name
# New Zealand    2013.5       1.821050e+11                           9.377544
# Norway         2013.5       4.542253e+11                           9.411250
# United States  2013.5       1.726294e+13                          16.338498
# France         2013.5       2.671145e+12                          11.364606
# Australia      2013.5       1.378422e+12                           9.326795
# ...               ...                ...                                ...
# Turkmenistan   2013.5       3.494974e+10                           4.363274
# Uzbekistan     2013.5       7.073790e+10                           5.070000
# Mongolia       2013.5       1.112285e+10                           4.079246
# Tajikistan     2013.5       7.519910e+09                           6.437500
# Colombia       2013.5       3.304462e+11                           7.191757
#
#                Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# New Zealand             0.341035              1.206371              0.666625
# Norway                  0.211370              0.856655              0.570766
# United States           0.335926              0.652297              0.525801
# France                  0.256829              0.960624              0.565579
# Australia               0.364632              1.146493              0.938357
# ...                          ...                   ...                   ...
# Turkmenistan            0.193885              0.666340              0.185643
# Uzbekistan              0.186496              0.667897              0.145255
# Mongolia                0.188450              0.653471              0.168233
# Tajikistan              0.180910              0.665022              0.113672
# Colombia                0.205024              0.765992              0.246970
#
#                Anxiety disorders (%)  Drug use disorders (%)  Depression (%)  \
# Country Name
# New Zealand                 8.537551                2.039562        3.973218
# Norway                      7.603229                0.867249        3.652384
# United States               6.667410                3.174581        4.786085
# France                      6.645552                1.209217        4.314880
# Australia                   6.604777                2.117433        4.738653
# ...                              ...                     ...             ...
# Turkmenistan                2.559913                0.514930        2.822227
# Uzbekistan                  2.553654                0.474298        2.884854
# Mongolia                    2.540770                0.526214        3.558683
# Tajikistan                  2.518310                0.462678        2.546354
# Colombia                    2.517587                1.101227        2.205738
#
#                Alcohol use disorders (%)  ...  \
# Country Name                              ...
# New Zealand                     1.985941  ...
# Norway                          1.427157  ...
# United States                   2.013025  ...
# France                          1.469359  ...
# Australia                       1.506636  ...
# ...                                  ...  ...
# Turkmenistan                    2.730036  ...
# Uzbekistan                      1.944910  ...
# Mongolia                        3.473308  ...
# Tajikistan                      2.231907  ...
# Colombia                        1.756655  ...
#
#                Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# New Zealand                                          3530.313359
# Norway                                               3358.983735
# United States                                        4350.217810
# France                                               3889.550780
# Australia                                            4223.273667
# ...                                                          ...
# Turkmenistan                                         2689.363182
# Uzbekistan                                           2775.791232
# Mongolia                                             3408.485676
# Tajikistan                                           2466.425061
# Colombia                                             2090.187567
#
#                GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# New Zealand            40152.331023              1.705010e+10
# Norway                 89323.830236              4.239259e+10
# United States          54348.025610              2.824040e+12
# France                 40445.144411              3.035214e+11
# Australia              59277.951124              1.283352e+11
# ...                             ...                       ...
# Turkmenistan            6205.414048              1.555889e+09
# Uzbekistan              2310.586715              3.559215e+09
# Mongolia                3851.116610              4.559613e+08
# Tajikistan               910.798802              4.870645e+08
# Colombia                7116.062692              2.368822e+10
#
#                Schizophrenia (#)  Bipolar disorder (#)  Eating disorders (#)  \
# Country Name
# New Zealand         1.544825e+04          5.464624e+04          3.020336e+04
# Norway              1.077412e+04          4.366572e+04          2.909368e+04
# United States       1.065734e+06          2.069513e+06          1.667848e+06
# France              1.696787e+05          6.346536e+05          3.736999e+05
# Australia           8.491118e+04          2.669812e+05          2.185733e+05
# ...                          ...                   ...                   ...
# Turkmenistan        1.089022e+04          3.741321e+04          1.044547e+04
# Uzbekistan          5.694526e+04          2.038961e+05          4.440767e+04
# Mongolia            5.437925e+03          1.885124e+04          4.862868e+03
# Tajikistan          1.492853e+04          5.486848e+04          9.390869e+03
# Colombia            9.533079e+04          3.561324e+05          1.149089e+05
#
#                Anxiety disorders (#)  Drug use disorders (#)  Depression (#)  \
# Country Name
# New Zealand             3.867386e+05            9.239531e+04    1.799727e+05
# Norway                  3.875403e+05            4.417429e+04    1.862473e+05
# United States           2.115255e+07            1.008020e+07    1.518609e+07
# France                  4.390497e+06            7.988254e+05    2.850551e+06
# Australia               1.538045e+06            4.940056e+05    1.102980e+06
# ...                              ...                     ...             ...
# Turkmenistan            1.437289e+05            2.891605e+04    1.584426e+05
# Uzbekistan              7.795925e+05            1.448423e+05    8.806522e+05
# Mongolia                7.331756e+04            1.518331e+04    1.026323e+05
# Tajikistan              2.077796e+05            3.819463e+04    2.101148e+05
# Colombia                1.170378e+06            5.118341e+05    1.025328e+06
#
#                Alcohol use disorders (#)
# Country Name
# New Zealand                 9.016646e+04
# Norway                      7.273997e+04
# United States               6.387442e+06
# France                      9.706188e+05
# Australia                   3.509128e+05
# ...                                  ...
# Turkmenistan                1.529717e+05
# Uzbekistan                  5.932254e+05
# Mongolia                    1.002013e+05
# Tajikistan                  1.840089e+05
# Colombia                    8.167092e+05
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Schizophrenia (%)", ascending=False)
# Out:
#                             Year  GDP (Current USD)  \
# Country Name
# Netherlands               2013.5       8.430523e+11
# Australia                 2013.5       1.378422e+12
# New Zealand               2013.5       1.821050e+11
# United States             2013.5       1.726294e+13
# China                     2013.5       9.602800e+12
# ...                          ...                ...
# Uganda                    2013.5       2.946436e+10
# Zimbabwe                  2013.5       1.749271e+10
# Mozambique                2013.5       1.492979e+10
# Malawi                    2013.5       9.181932e+09
# Central African Republic  2013.5       2.033782e+09
#
#                           Percentage GDP Health Expenditure  \
# Country Name
# Netherlands                                       10.321250
# Australia                                          9.326795
# New Zealand                                        9.377544
# United States                                     16.338498
# China                                              4.701981
# ...                                                     ...
# Uganda                                             5.595820
# Zimbabwe                                           7.749776
# Mozambique                                         6.247805
# Malawi                                             6.693636
# Central African Republic                           4.704590
#
#                           Schizophrenia (%)  Bipolar disorder (%)  \
# Country Name
# Netherlands                        0.368098              0.947372
# Australia                          0.364632              1.146493
# New Zealand                        0.341035              1.206371
# United States                      0.335926              0.652297
# China                              0.334502              0.322203
# ...                                     ...                   ...
# Uganda                             0.159126              0.608530
# Zimbabwe                           0.156167              0.608620
# Mozambique                         0.155110              0.609605
# Malawi                             0.153874              0.604252
# Central African Republic           0.148613              0.592444
#
#                           Eating disorders (%)  Anxiety disorders (%)  \
# Country Name
# Netherlands                           0.460789               6.561230
# Australia                             0.938357               6.604777
# New Zealand                           0.666625               8.537551
# United States                         0.525801               6.667410
# China                                 0.145970               3.094039
# ...                                        ...                    ...
# Uganda                                0.115132               3.501130
# Zimbabwe                              0.118757               3.094277
# Mozambique                            0.098899               3.644036
# Malawi                                0.098740               3.627612
# Central African Republic              0.091134               3.242837
#
#                           Drug use disorders (%)  Depression (%)  \
# Country Name
# Netherlands                             0.951262        4.031707
# Australia                               2.117433        4.738653
# New Zealand                             2.039562        3.973218
# United States                           3.174581        4.786085
# China                                   1.064983        3.368524
# ...                                          ...             ...
# Uganda                                  0.537489        5.052701
# Zimbabwe                                0.766560        3.140522
# Mozambique                              0.519453        3.886165
# Malawi                                  0.502463        3.374782
# Central African Republic                0.512231        4.217063
#
#                           Alcohol use disorders (%)  ...  \
# Country Name                                         ...
# Netherlands                                0.745190  ...
# Australia                                  1.506636  ...
# New Zealand                                1.985941  ...
# United States                              2.013025  ...
# China                                      1.229753  ...
# ...                                             ...  ...
# Uganda                                     1.290151  ...
# Zimbabwe                                   1.514469  ...
# Mozambique                                 1.692379  ...
# Malawi                                     1.609120  ...
# Central African Republic                   1.419790  ...
#
#                           Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# Netherlands                                                     3676.427949
# Australia                                                       4223.273667
# New Zealand                                                     3530.313359
# United States                                                   4350.217810
# China                                                           3168.357908
# ...                                                                     ...
# Uganda                                                          4989.112273
# Zimbabwe                                                        3057.056957
# Mozambique                                                      3829.203093
# Malawi                                                          3312.906444
# Central African Republic                                        4181.844082
#
#                           GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# Netherlands                       50038.420760              8.705256e+10
# Australia                         59277.951124              1.283352e+11
# New Zealand                       40152.331023              1.705010e+10
# United States                     54348.025610              2.824040e+12
# China                              7006.222991              4.570069e+11
# ...                                        ...                       ...
# Uganda                              819.981795              1.635564e+09
# Zimbabwe                           1268.784519              1.333562e+09
# Mozambique                          583.344671              9.283446e+08
# Malawi                              569.307896              6.046772e+08
# Central African Republic            423.336664              9.429808e+07
#
#                           Schizophrenia (#)  Bipolar disorder (#)  \
# Country Name
# Netherlands                    6.203158e+04          1.596730e+05
# Australia                      8.491118e+04          2.669812e+05
# New Zealand                    1.544825e+04          5.464624e+04
# United States                  1.065734e+06          2.069513e+06
# China                          4.573022e+06          4.404424e+06
# ...                                     ...                   ...
# Uganda                         5.727838e+04          2.190046e+05
# Zimbabwe                       2.145901e+04          8.361897e+04
# Mozambique                     3.989969e+04          1.567787e+05
# Malawi                         2.504229e+04          9.833441e+04
# Central African Republic       7.149772e+03          2.850197e+04
#
#                           Eating disorders (#)  Anxiety disorders (#)  \
# Country Name
# Netherlands                       7.767111e+04           1.105903e+06
# Australia                         2.185733e+05           1.538045e+06
# New Zealand                       3.020336e+04           3.867386e+05
# United States                     1.667848e+06           2.115255e+07
# China                             1.997080e+06           4.228740e+07
# ...                                        ...                    ...
# Uganda                            4.149830e+04           1.260244e+06
# Zimbabwe                          1.633064e+04           4.251366e+05
# Mozambique                        2.548350e+04           9.373756e+05
# Malawi                            1.607901e+04           5.904829e+05
# Central African Republic          4.383256e+03           1.560119e+05
#
#                           Drug use disorders (#)  Depression (#)  \
# Country Name
# Netherlands                         1.603619e+05    6.795109e+05
# Australia                           4.940056e+05    1.102980e+06
# New Zealand                         9.239531e+04    1.799727e+05
# United States                       1.008020e+07    1.518609e+07
# China                               1.456321e+07    4.604112e+07
# ...                                          ...             ...
# Uganda                              1.934878e+05    1.815970e+06
# Zimbabwe                            1.053415e+05    4.316194e+05
# Mozambique                          1.336776e+05    9.995043e+05
# Malawi                              8.179867e+04    5.495240e+05
# Central African Republic            2.464480e+04    2.028734e+05
#
#                           Alcohol use disorders (#)
# Country Name
# Netherlands                            1.256250e+05
# Australia                              3.509128e+05
# New Zealand                            9.016646e+04
# United States                          6.387442e+06
# China                                  1.681031e+07
# ...                                             ...
# Uganda                                 4.643421e+05
# Zimbabwe                               2.080444e+05
# Mozambique                             4.353749e+05
# Malawi                                 2.618060e+05
# Central African Republic               6.829771e+04
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Bipolar disorder (%)", ascending=False)
# Out:
#                     Year  GDP (Current USD)  \
# Country Name
# New Zealand       2013.5       1.821050e+11
# Australia         2013.5       1.378422e+12
# Brazil            2013.5       2.235063e+12
# United Kingdom    2013.5       2.750388e+12
# Paraguay          2013.5       3.555830e+10
# ...                  ...                ...
# Fiji              2013.5       4.363105e+09
# Solomon Islands   2013.5       1.240740e+09
# Vanuatu           2013.5       7.638936e+08
# Papua New Guinea  2013.5       2.040353e+10
# China             2013.5       9.602800e+12
#
#                   Percentage GDP Health Expenditure  Schizophrenia (%)  \
# Country Name
# New Zealand                                9.377544           0.341035
# Australia                                  9.326795           0.364632
# Brazil                                     8.424043           0.204985
# United Kingdom                             9.832774           0.256563
# Paraguay                                   6.310921           0.200901
# ...                                             ...                ...
# Fiji                                       3.273190           0.237651
# Solomon Islands                            4.628046           0.209428
# Vanuatu                                    3.639407           0.214871
# Papua New Guinea                           2.464513           0.207556
# China                                      4.701981           0.334502
#
#                   Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# New Zealand                   1.206371              0.666625
# Australia                     1.146493              0.938357
# Brazil                        1.106712              0.270179
# United Kingdom                1.085697              0.542064
# Paraguay                      1.074124              0.229334
# ...                                ...                   ...
# Fiji                          0.451486              0.143590
# Solomon Islands               0.427262              0.091229
# Vanuatu                       0.427027              0.105290
# Papua New Guinea              0.410760              0.100745
# China                         0.322203              0.145970
#
#                   Anxiety disorders (%)  Drug use disorders (%)  \
# Country Name
# New Zealand                    8.537551                2.039562
# Australia                      6.604777                2.117433
# Brazil                         6.263148                1.047308
# United Kingdom                 4.660086                1.716030
# Paraguay                       6.007477                0.531825
# ...                                 ...                     ...
# Fiji                           3.272276                0.750535
# Solomon Islands                3.207645                0.691640
# Vanuatu                        3.215815                0.683581
# Papua New Guinea               3.188208                0.729244
# China                          3.094039                1.064983
#
#                   Depression (%)  Alcohol use disorders (%)  ...  \
# Country Name                                                 ...
# New Zealand             3.973218                   1.985941  ...
# Australia               4.738653                   1.506636  ...
# Brazil                  3.373768                   2.699771  ...
# United Kingdom          4.124592                   1.911949  ...
# Paraguay                2.942449                   2.342874  ...
# ...                          ...                        ...  ...
# Fiji                    3.178043                   1.102947  ...
# Solomon Islands         3.169442                   1.136224  ...
# Vanuatu                 3.139916                   1.209627  ...
# Papua New Guinea        3.184431                   1.208409  ...
# China                   3.368524                   1.229753  ...
#
#                   Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# New Zealand                                             3530.313359
# Australia                                               4223.273667
# Brazil                                                  3229.418622
# United Kingdom                                          3774.543605
# Paraguay                                                2832.563607
# ...                                                             ...
# Fiji                                                    3083.046248
# Solomon Islands                                         3122.976771
# Vanuatu                                                 3089.532503
# Papua New Guinea                                        3141.078211
# China                                                   3168.357908
#
#                   GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# New Zealand               40152.331023              1.705010e+10
# Australia                 59277.951124              1.283352e+11
# Brazil                    11058.500273              1.867608e+11
# United Kingdom            42699.200249              2.704262e+11
# Paraguay                   5864.480900              2.256123e+09
# ...                                ...                       ...
# Fiji                       4772.563202              1.426853e+08
# Solomon Islands            2091.169934              5.713998e+07
# Vanuatu                    2859.447517              2.763240e+07
# Papua New Guinea           2435.849845              5.079247e+08
# China                      7006.222991              4.570069e+11
#
#                   Schizophrenia (#)  Bipolar disorder (#)  \
# Country Name
# New Zealand            1.544825e+04          5.464624e+04
# Australia              8.491118e+04          2.669812e+05
# Brazil                 4.151737e+05          2.241451e+06
# United Kingdom         1.652774e+05          6.992528e+05
# Paraguay               1.216439e+04          6.502991e+04
# ...                             ...                   ...
# Fiji                   2.171021e+03          4.124462e+03
# Solomon Islands        1.237408e+03          2.524147e+03
# Vanuatu                5.740860e+02          1.140959e+03
# Papua New Guinea       1.734261e+04          3.431110e+04
# China                  4.573022e+06          4.404424e+06
#
#                   Eating disorders (#)  Anxiety disorders (#)  \
# Country Name
# New Zealand               3.020336e+04           3.867386e+05
# Australia                 2.185733e+05           1.538045e+06
# Brazil                    5.473838e+05           1.268058e+07
# United Kingdom            3.491306e+05           3.001277e+06
# Paraguay                  1.389480e+04           3.637054e+05
# ...                                ...                    ...
# Fiji                      1.311831e+03           2.989328e+04
# Solomon Islands           5.395427e+02           1.895079e+04
# Vanuatu                   2.814159e+02           8.592229e+03
# Papua New Guinea          8.427349e+03           2.663176e+05
# China                     1.997080e+06           4.228740e+07
#
#                   Drug use disorders (#)  Depression (#)  \
# Country Name
# New Zealand                 9.239531e+04    1.799727e+05
# Australia                   4.940056e+05    1.102980e+06
# Brazil                      2.121516e+06    6.830304e+06
# United Kingdom              1.104884e+06    2.656435e+06
# Paraguay                    3.219402e+04    1.781591e+05
# ...                                  ...             ...
# Fiji                        6.856506e+03    2.903208e+04
# Solomon Islands             4.088198e+03    1.872063e+04
# Vanuatu                     1.827597e+03    8.387857e+03
# Papua New Guinea            6.093882e+04    2.659512e+05
# China                       1.456321e+07    4.604112e+07
#
#                   Alcohol use disorders (#)
# Country Name
# New Zealand                    9.016646e+04
# Australia                      3.509128e+05
# Brazil                         5.467555e+06
# United Kingdom                 1.231361e+06
# Paraguay                       1.418882e+05
# ...                                     ...
# Fiji                           1.007586e+04
# Solomon Islands                6.712200e+03
# Vanuatu                        3.232364e+03
# Papua New Guinea               1.009507e+05
# China                          1.681031e+07
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Eating disorders (%)", ascending=False)
# Out:
#                             Year  GDP (Current USD)  \
# Country Name
# Australia                 2013.5       1.378422e+12
# Luxembourg                2013.5       6.246192e+10
# Spain                     2013.5       1.337241e+12
# Austria                   2013.5       4.126509e+11
# New Zealand               2013.5       1.821050e+11
# ...                          ...                ...
# Malawi                    2013.5       9.181932e+09
# Niger                     2013.5       9.800841e+09
# Solomon Islands           2013.5       1.240740e+09
# Central African Republic  2013.5       2.033782e+09
# Liberia                   2013.5       2.950833e+09
#
#                           Percentage GDP Health Expenditure  \
# Country Name
# Australia                                          9.326795
# Luxembourg                                         5.457500
# Spain                                              9.075520
# Austria                                           10.276250
# New Zealand                                        9.377544
# ...                                                     ...
# Malawi                                             6.693636
# Niger                                              4.814706
# Solomon Islands                                    4.628046
# Central African Republic                           4.704590
# Liberia                                            9.365768
#
#                           Schizophrenia (%)  Bipolar disorder (%)  \
# Country Name
# Australia                          0.364632              1.146493
# Luxembourg                         0.263253              0.934343
# Spain                              0.280560              0.976727
# Austria                            0.256487              0.939852
# New Zealand                        0.341035              1.206371
# ...                                     ...                   ...
# Malawi                             0.153874              0.604252
# Niger                              0.162934              0.630350
# Solomon Islands                    0.209428              0.427262
# Central African Republic           0.148613              0.592444
# Liberia                            0.160298              0.629525
#
#                           Eating disorders (%)  Anxiety disorders (%)  \
# Country Name
# Australia                             0.938357               6.604777
# Luxembourg                            0.735785               5.319169
# Spain                                 0.728582               5.276022
# Austria                               0.672592               5.347553
# New Zealand                           0.666625               8.537551
# ...                                        ...                    ...
# Malawi                                0.098740               3.627612
# Niger                                 0.092938               2.883563
# Solomon Islands                       0.091229               3.207645
# Central African Republic              0.091134               3.242837
# Liberia                               0.088140               2.872913
#
#                           Drug use disorders (%)  Depression (%)  \
# Country Name
# Australia                               2.117433        4.738653
# Luxembourg                              0.945731        3.621437
# Spain                                   1.434022        3.490751
# Austria                                 0.911160        3.272791
# New Zealand                             2.039562        3.973218
# ...                                          ...             ...
# Malawi                                  0.502463        3.374782
# Niger                                   0.453464        3.447353
# Solomon Islands                         0.691640        3.169442
# Central African Republic                0.512231        4.217063
# Liberia                                 0.508874        3.780322
#
#                           Alcohol use disorders (%)  ...  \
# Country Name                                         ...
# Australia                                  1.506636  ...
# Luxembourg                                 1.368974  ...
# Spain                                      0.897441  ...
# Austria                                    1.905054  ...
# New Zealand                                1.985941  ...
# ...                                             ...  ...
# Malawi                                     1.609120  ...
# Niger                                      0.909325  ...
# Solomon Islands                            1.136224  ...
# Central African Republic                   1.419790  ...
# Liberia                                    0.948187  ...
#
#                           Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# Australia                                                       4223.273667
# Luxembourg                                                      3331.782688
# Spain                                                           3185.815404
# Austria                                                         3005.089420
# New Zealand                                                     3530.313359
# ...                                                                     ...
# Malawi                                                          3312.906444
# Niger                                                           3412.460457
# Solomon Islands                                                 3122.976771
# Central African Republic                                        4181.844082
# Liberia                                                         3746.553100
#
#                           GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# Australia                         59277.951124              1.283352e+11
# Luxembourg                       113591.135957              3.396967e+09
# Spain                             28700.125316              1.213940e+11
# Austria                           48295.127939              4.240019e+10
# New Zealand                       40152.331023              1.705010e+10
# ...                                        ...                       ...
# Malawi                              569.307896              6.046772e+08
# Niger                               513.233202              4.720518e+08
# Solomon Islands                    2091.169934              5.713998e+07
# Central African Republic            423.336664              9.429808e+07
# Liberia                             659.382483              2.756352e+08
#
#                           Schizophrenia (#)  Bipolar disorder (#)  \
# Country Name
# Australia                      84911.184275         266981.194038
# Luxembourg                      1449.230505           5143.437129
# Spain                         130711.326028         455051.802889
# Austria                        21926.191348          80343.306050
# New Zealand                    15448.245982          54646.241020
# ...                                     ...                   ...
# Malawi                         25042.291476          98334.410819
# Niger                          31108.221873         120327.096879
# Solomon Islands                 1237.407691           2524.147385
# Central African Republic        7149.772467          28501.972410
# Liberia                         7133.750308          28010.925071
#
#                           Eating disorders (#)  Anxiety disorders (#)  \
# Country Name
# Australia                        218573.301037           1.538045e+06
# Luxembourg                         4051.014647           2.928042e+04
# Spain                            339439.230549           2.458068e+06
# Austria                           57499.967466           4.571304e+05
# New Zealand                       30203.358380           3.867386e+05
# ...                                        ...                    ...
# Malawi                            16079.009877           5.904829e+05
# Niger                             17770.125815           5.504591e+05
# Solomon Islands                     539.542682           1.895079e+04
# Central African Republic           4383.255621           1.560119e+05
# Liberia                            3926.665163           1.278364e+05
#
#                           Drug use disorders (#)  Depression (#)  \
# Country Name
# Australia                          494005.570082    1.102980e+06
# Luxembourg                           5203.825286    1.993383e+04
# Spain                              668090.009862    1.626305e+06
# Austria                             77885.054088    2.797607e+05
# New Zealand                         92395.308544    1.799727e+05
# ...                                          ...             ...
# Malawi                              81798.674691    5.495240e+05
# Niger                               86650.133145    6.581496e+05
# Solomon Islands                      4088.197877    1.872063e+04
# Central African Republic            24644.797151    2.028734e+05
# Liberia                             22651.036225    1.682275e+05
#
#                           Alcohol use disorders (#)
# Country Name
# Australia                             350912.789831
# Luxembourg                              7533.285732
# Spain                                 418116.253953
# Austria                               162787.181049
# New Zealand                            90166.459947
# ...                                             ...
# Malawi                                261805.963284
# Niger                                 173586.238726
# Solomon Islands                         6712.200050
# Central African Republic               68297.710898
# Liberia                                42191.779842
#
# [140 rows x 31 columns]

# %% [markdown]
# ### Sorted Mean Disorder Numbers by Country

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Depression (#)", ascending=False)
# Out:
#                          Year  GDP (Current USD)  \
# Country Name
# China                  2013.5       9.602800e+12
# India                  2013.5       2.034002e+12
# United States          2013.5       1.726294e+13
# Nigeria                2013.5       4.516438e+11
# Brazil                 2013.5       2.235063e+12
# ...                       ...                ...
# Belize                 2013.5       2.038282e+09
# Vanuatu                2013.5       7.638936e+08
# Barbados               2013.5       4.726552e+09
# Samoa                  2013.5       7.931049e+08
# Sao Tome and Principe  2013.5       2.600348e+08
#
#                        Percentage GDP Health Expenditure  Schizophrenia (%)  \
# Country Name
# China                                           4.701981           0.334502
# India                                           3.407500           0.261514
# United States                                  16.338498           0.335926
# Nigeria                                         3.465446           0.180741
# Brazil                                          8.424043           0.204985
# ...                                                  ...                ...
# Belize                                          4.595085           0.194571
# Vanuatu                                         3.639407           0.214871
# Barbados                                        7.016591           0.230130
# Samoa                                           5.625101           0.234937
# Sao Tome and Principe                           6.624830           0.177592
#
#                        Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# China                              0.322203              0.145970
# India                              0.555935              0.146703
# United States                      0.652297              0.525801
# Nigeria                            0.642524              0.156859
# Brazil                             1.106712              0.270179
# ...                                     ...                   ...
# Belize                             0.880364              0.255608
# Vanuatu                            0.427027              0.105290
# Barbados                           0.919692              0.324001
# Samoa                              0.460435              0.125234
# Sao Tome and Principe              0.662652              0.129756
#
#                        Anxiety disorders (%)  Drug use disorders (%)  \
# Country Name
# China                               3.094039                1.064983
# India                               3.292028                0.512375
# United States                       6.667410                3.174581
# Nigeria                             2.909322                0.454845
# Brazil                              6.263148                1.047308
# ...                                      ...                     ...
# Belize                              4.557809                0.831608
# Vanuatu                             3.215815                0.683581
# Barbados                            4.664651                0.844089
# Samoa                               3.255870                0.856471
# Sao Tome and Principe               2.918029                0.481449
#
#                        Depression (%)  Alcohol use disorders (%)  ...  \
# Country Name                                                      ...
# China                        3.368524                   1.229753  ...
# India                        3.519355                   1.149992  ...
# United States                4.786085                   2.013025  ...
# Nigeria                      4.117378                   0.961843  ...
# Brazil                       3.373768                   2.699771  ...
# ...                               ...                        ...  ...
# Belize                       2.838086                   1.766149  ...
# Vanuatu                      3.139916                   1.209627  ...
# Barbados                     2.752176                   1.590162  ...
# Samoa                        3.053512                   1.109336  ...
# Sao Tome and Principe        3.112706                   1.010334  ...
#
#                        Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# China                                                        3168.357908
# India                                                        3460.609565
# United States                                                4350.217810
# Nigeria                                                      4063.440656
# Brazil                                                       3229.418622
# ...                                                                  ...
# Belize                                                       2727.326827
# Vanuatu                                                      3089.532503
# Barbados                                                     2605.323089
# Samoa                                                        2964.920225
# Sao Tome and Principe                                        3043.673023
#
#                        GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# China                           7006.222991              4.570069e+11
# India                           1561.825028              6.904325e+10
# United States                  54348.025610              2.824040e+12
# Nigeria                         2557.117107              1.562123e+10
# Brazil                         11058.500273              1.867608e+11
# ...                                     ...                       ...
# Belize                          5837.361382              9.384594e+07
# Vanuatu                         2859.447517              2.763240e+07
# Barbados                       17056.346071              3.314429e+08
# Samoa                           3942.609898              4.468664e+07
# Sao Tome and Principe           1324.926020              1.720172e+07
#
#                        Schizophrenia (#)  Bipolar disorder (#)  \
# Country Name
# China                       4.573022e+06          4.404424e+06
# India                       3.394645e+06          7.218256e+06
# United States               1.065734e+06          2.069513e+06
# Nigeria                     3.201859e+05          1.138018e+06
# Brazil                      4.151737e+05          2.241451e+06
# ...                                  ...                   ...
# Belize                      6.780242e+02          3.067772e+03
# Vanuatu                     5.740860e+02          1.140959e+03
# Barbados                    6.376469e+02          2.548320e+03
# Samoa                       4.721048e+02          9.252363e+02
# Sao Tome and Principe       3.470517e+02          1.294825e+03
#
#                        Eating disorders (#)  Anxiety disorders (#)  \
# Country Name
# China                          1.997080e+06           4.228740e+07
# India                          1.907310e+06           4.274406e+07
# United States                  1.667848e+06           2.115255e+07
# Nigeria                        2.783199e+05           5.152905e+06
# Brazil                         5.473838e+05           1.268058e+07
# ...                                     ...                    ...
# Belize                         8.910494e+02           1.588286e+04
# Vanuatu                        2.814159e+02           8.592229e+03
# Barbados                       8.977272e+02           1.292498e+04
# Samoa                          2.516850e+02           6.542632e+03
# Sao Tome and Principe          2.538018e+02           5.701819e+03
#
#                        Drug use disorders (#)  Depression (#)  \
# Country Name
# China                            1.456321e+07    4.604112e+07
# India                            6.655644e+06    4.569380e+07
# United States                    1.008020e+07    1.518609e+07
# Nigeria                          8.059223e+05    7.281066e+06
# Brazil                           2.121516e+06    6.830304e+06
# ...                                       ...             ...
# Belize                           2.898057e+03    9.889249e+03
# Vanuatu                          1.827597e+03    8.387857e+03
# Barbados                         2.338805e+03    7.625932e+03
# Samoa                            1.720831e+03    6.135594e+03
# Sao Tome and Principe            9.414931e+02    6.082968e+03
#
#                        Alcohol use disorders (#)
# Country Name
# China                               1.681031e+07
# India                               1.492206e+07
# United States                       6.387442e+06
# Nigeria                             1.703667e+06
# Brazil                              5.467555e+06
# ...                                          ...
# Belize                              6.155853e+03
# Vanuatu                             3.232364e+03
# Barbados                            4.405995e+03
# Samoa                               2.229236e+03
# Sao Tome and Principe               1.974535e+03
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Drug use disorders (#)", ascending=False)
# Out:
#                          Year  GDP (Current USD)  \
# Country Name
# China                  2013.5       9.602800e+12
# United States          2013.5       1.726294e+13
# India                  2013.5       2.034002e+12
# Brazil                 2013.5       2.235063e+12
# Indonesia              2013.5       8.972028e+11
# ...                       ...                ...
# Barbados               2013.5       4.726552e+09
# Iceland                2013.5       1.759446e+10
# Vanuatu                2013.5       7.638936e+08
# Samoa                  2013.5       7.931049e+08
# Sao Tome and Principe  2013.5       2.600348e+08
#
#                        Percentage GDP Health Expenditure  Schizophrenia (%)  \
# Country Name
# China                                           4.701981           0.334502
# United States                                  16.338498           0.335926
# India                                           3.407500           0.261514
# Brazil                                          8.424043           0.204985
# Indonesia                                       2.922273           0.227120
# ...                                                  ...                ...
# Barbados                                        7.016591           0.230130
# Iceland                                         8.197500           0.257060
# Vanuatu                                         3.639407           0.214871
# Samoa                                           5.625101           0.234937
# Sao Tome and Principe                           6.624830           0.177592
#
#                        Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# China                              0.322203              0.145970
# United States                      0.652297              0.525801
# India                              0.555935              0.146703
# Brazil                             1.106712              0.270179
# Indonesia                          0.539603              0.138858
# ...                                     ...                   ...
# Barbados                           0.919692              0.324001
# Iceland                            0.967943              0.552809
# Vanuatu                            0.427027              0.105290
# Samoa                              0.460435              0.125234
# Sao Tome and Principe              0.662652              0.129756
#
#                        Anxiety disorders (%)  Drug use disorders (%)  \
# Country Name
# China                               3.094039                1.064983
# United States                       6.667410                3.174581
# India                               3.292028                0.512375
# Brazil                              6.263148                1.047308
# Indonesia                           3.274802                0.576971
# ...                                      ...                     ...
# Barbados                            4.664651                0.844089
# Iceland                             5.290576                0.696816
# Vanuatu                             3.215815                0.683581
# Samoa                               3.255870                0.856471
# Sao Tome and Principe               2.918029                0.481449
#
#                        Depression (%)  Alcohol use disorders (%)  ...  \
# Country Name                                                      ...
# China                        3.368524                   1.229753  ...
# United States                4.786085                   2.013025  ...
# India                        3.519355                   1.149992  ...
# Brazil                       3.373768                   2.699771  ...
# Indonesia                    2.621234                   0.647895  ...
# ...                               ...                        ...  ...
# Barbados                     2.752176                   1.590162  ...
# Iceland                      3.360880                   1.224493  ...
# Vanuatu                      3.139916                   1.209627  ...
# Samoa                        3.053512                   1.109336  ...
# Sao Tome and Principe        3.112706                   1.010334  ...
#
#                        Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# China                                                        3168.357908
# United States                                                4350.217810
# India                                                        3460.609565
# Brazil                                                       3229.418622
# Indonesia                                                    2549.945462
# ...                                                                  ...
# Barbados                                                     2605.323089
# Iceland                                                      3107.366705
# Vanuatu                                                      3089.532503
# Samoa                                                        2964.920225
# Sao Tome and Principe                                        3043.673023
#
#                        GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# China                           7006.222991              4.570069e+11
# United States                  54348.025610              2.824040e+12
# India                           1561.825028              6.904325e+10
# Brazil                         11058.500273              1.867608e+11
# Indonesia                       3522.144003              2.624168e+10
# ...                                     ...                       ...
# Barbados                       17056.346071              3.314429e+08
# Iceland                        53534.837222              1.441803e+09
# Vanuatu                         2859.447517              2.763240e+07
# Samoa                           3942.609898              4.468664e+07
# Sao Tome and Principe           1324.926020              1.720172e+07
#
#                        Schizophrenia (#)  Bipolar disorder (#)  \
# Country Name
# China                       4.573022e+06          4.404424e+06
# United States               1.065734e+06          2.069513e+06
# India                       3.394645e+06          7.218256e+06
# Brazil                      4.151737e+05          2.241451e+06
# Indonesia                   5.782293e+05          1.373521e+06
# ...                                  ...                   ...
# Barbados                    6.376469e+02          2.548320e+03
# Iceland                     8.414355e+02          3.168453e+03
# Vanuatu                     5.740860e+02          1.140959e+03
# Samoa                       4.721048e+02          9.252363e+02
# Sao Tome and Principe       3.470517e+02          1.294825e+03
#
#                        Eating disorders (#)  Anxiety disorders (#)  \
# Country Name
# China                          1.997080e+06           4.228740e+07
# United States                  1.667848e+06           2.115255e+07
# India                          1.907310e+06           4.274406e+07
# Brazil                         5.473838e+05           1.268058e+07
# Indonesia                      3.538496e+05           8.335739e+06
# ...                                     ...                    ...
# Barbados                       8.977272e+02           1.292498e+04
# Iceland                        1.809819e+03           1.731741e+04
# Vanuatu                        2.814159e+02           8.592229e+03
# Samoa                          2.516850e+02           6.542632e+03
# Sao Tome and Principe          2.538018e+02           5.701819e+03
#
#                        Drug use disorders (#)  Depression (#)  \
# Country Name
# China                            1.456321e+07    4.604112e+07
# United States                    1.008020e+07    1.518609e+07
# India                            6.655644e+06    4.569380e+07
# Brazil                           2.121516e+06    6.830304e+06
# Indonesia                        1.469086e+06    6.672680e+06
# ...                                       ...             ...
# Barbados                         2.338805e+03    7.625932e+03
# Iceland                          2.282068e+03    1.100091e+04
# Vanuatu                          1.827597e+03    8.387857e+03
# Samoa                            1.720831e+03    6.135594e+03
# Sao Tome and Principe            9.414931e+02    6.082968e+03
#
#                        Alcohol use disorders (#)
# Country Name
# China                               1.681031e+07
# United States                       6.387442e+06
# India                               1.492206e+07
# Brazil                              5.467555e+06
# Indonesia                           1.649272e+06
# ...                                          ...
# Barbados                            4.405995e+03
# Iceland                             4.009162e+03
# Vanuatu                             3.232364e+03
# Samoa                               2.229236e+03
# Sao Tome and Principe               1.974535e+03
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Alcohol use disorders (#)", ascending=False)
# Out:
#                          Year  GDP (Current USD)  \
# Country Name
# China                  2013.5       9.602800e+12
# India                  2013.5       2.034002e+12
# United States          2013.5       1.726294e+13
# Brazil                 2013.5       2.235063e+12
# Pakistan               2013.5       2.700313e+11
# ...                       ...                ...
# Barbados               2013.5       4.726552e+09
# Iceland                2013.5       1.759446e+10
# Vanuatu                2013.5       7.638936e+08
# Samoa                  2013.5       7.931049e+08
# Sao Tome and Principe  2013.5       2.600348e+08
#
#                        Percentage GDP Health Expenditure  Schizophrenia (%)  \
# Country Name
# China                                           4.701981           0.334502
# India                                           3.407500           0.261514
# United States                                  16.338498           0.335926
# Brazil                                          8.424043           0.204985
# Pakistan                                        2.426181           0.256468
# ...                                                  ...                ...
# Barbados                                        7.016591           0.230130
# Iceland                                         8.197500           0.257060
# Vanuatu                                         3.639407           0.214871
# Samoa                                           5.625101           0.234937
# Sao Tome and Principe                           6.624830           0.177592
#
#                        Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# China                              0.322203              0.145970
# India                              0.555935              0.146703
# United States                      0.652297              0.525801
# Brazil                             1.106712              0.270179
# Pakistan                           0.573501              0.150134
# ...                                     ...                   ...
# Barbados                           0.919692              0.324001
# Iceland                            0.967943              0.552809
# Vanuatu                            0.427027              0.105290
# Samoa                              0.460435              0.125234
# Sao Tome and Principe              0.662652              0.129756
#
#                        Anxiety disorders (%)  Drug use disorders (%)  \
# Country Name
# China                               3.094039                1.064983
# India                               3.292028                0.512375
# United States                       6.667410                3.174581
# Brazil                              6.263148                1.047308
# Pakistan                            3.816029                0.673662
# ...                                      ...                     ...
# Barbados                            4.664651                0.844089
# Iceland                             5.290576                0.696816
# Vanuatu                             3.215815                0.683581
# Samoa                               3.255870                0.856471
# Sao Tome and Principe               2.918029                0.481449
#
#                        Depression (%)  Alcohol use disorders (%)  ...  \
# Country Name                                                      ...
# China                        3.368524                   1.229753  ...
# India                        3.519355                   1.149992  ...
# United States                4.786085                   2.013025  ...
# Brazil                       3.373768                   2.699771  ...
# Pakistan                     3.310687                   1.516488  ...
# ...                               ...                        ...  ...
# Barbados                     2.752176                   1.590162  ...
# Iceland                      3.360880                   1.224493  ...
# Vanuatu                      3.139916                   1.209627  ...
# Samoa                        3.053512                   1.109336  ...
# Sao Tome and Principe        3.112706                   1.010334  ...
#
#                        Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# China                                                        3168.357908
# India                                                        3460.609565
# United States                                                4350.217810
# Brazil                                                       3229.418622
# Pakistan                                                     3218.450761
# ...                                                                  ...
# Barbados                                                     2605.323089
# Iceland                                                      3107.366705
# Vanuatu                                                      3089.532503
# Samoa                                                        2964.920225
# Sao Tome and Principe                                        3043.673023
#
#                        GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# China                           7006.222991              4.570069e+11
# India                           1561.825028              6.904325e+10
# United States                  54348.025610              2.824040e+12
# Brazil                         11058.500273              1.867608e+11
# Pakistan                        1303.835747              6.614426e+09
# ...                                     ...                       ...
# Barbados                       17056.346071              3.314429e+08
# Iceland                        53534.837222              1.441803e+09
# Vanuatu                         2859.447517              2.763240e+07
# Samoa                           3942.609898              4.468664e+07
# Sao Tome and Principe           1324.926020              1.720172e+07
#
#                        Schizophrenia (#)  Bipolar disorder (#)  \
# Country Name
# China                       4.573022e+06          4.404424e+06
# India                       3.394645e+06          7.218256e+06
# United States               1.065734e+06          2.069513e+06
# Brazil                      4.151737e+05          2.241451e+06
# Pakistan                    5.288820e+05          1.182689e+06
# ...                                  ...                   ...
# Barbados                    6.376469e+02          2.548320e+03
# Iceland                     8.414355e+02          3.168453e+03
# Vanuatu                     5.740860e+02          1.140959e+03
# Samoa                       4.721048e+02          9.252363e+02
# Sao Tome and Principe       3.470517e+02          1.294825e+03
#
#                        Eating disorders (#)  Anxiety disorders (#)  \
# Country Name
# China                          1.997080e+06           4.228740e+07
# India                          1.907310e+06           4.274406e+07
# United States                  1.667848e+06           2.115255e+07
# Brazil                         5.473838e+05           1.268058e+07
# Pakistan                       3.098181e+05           7.869688e+06
# ...                                     ...                    ...
# Barbados                       8.977272e+02           1.292498e+04
# Iceland                        1.809819e+03           1.731741e+04
# Vanuatu                        2.814159e+02           8.592229e+03
# Samoa                          2.516850e+02           6.542632e+03
# Sao Tome and Principe          2.538018e+02           5.701819e+03
#
#                        Drug use disorders (#)  Depression (#)  \
# Country Name
# China                            1.456321e+07    4.604112e+07
# India                            6.655644e+06    4.569380e+07
# United States                    1.008020e+07    1.518609e+07
# Brazil                           2.121516e+06    6.830304e+06
# Pakistan                         1.388571e+06    6.827566e+06
# ...                                       ...             ...
# Barbados                         2.338805e+03    7.625932e+03
# Iceland                          2.282068e+03    1.100091e+04
# Vanuatu                          1.827597e+03    8.387857e+03
# Samoa                            1.720831e+03    6.135594e+03
# Sao Tome and Principe            9.414931e+02    6.082968e+03
#
#                        Alcohol use disorders (#)
# Country Name
# China                               1.681031e+07
# India                               1.492206e+07
# United States                       6.387442e+06
# Brazil                              5.467555e+06
# Pakistan                            3.128077e+06
# ...                                          ...
# Barbados                            4.405995e+03
# Iceland                             4.009162e+03
# Vanuatu                             3.232364e+03
# Samoa                               2.229236e+03
# Sao Tome and Principe               1.974535e+03
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Anxiety disorders (#)", ascending=False)
# Out:
#                          Year  GDP (Current USD)  \
# Country Name
# India                  2013.5       2.034002e+12
# China                  2013.5       9.602800e+12
# United States          2013.5       1.726294e+13
# Brazil                 2013.5       2.235063e+12
# Indonesia              2013.5       8.972028e+11
# ...                       ...                ...
# Belize                 2013.5       2.038282e+09
# Barbados               2013.5       4.726552e+09
# Vanuatu                2013.5       7.638936e+08
# Samoa                  2013.5       7.931049e+08
# Sao Tome and Principe  2013.5       2.600348e+08
#
#                        Percentage GDP Health Expenditure  Schizophrenia (%)  \
# Country Name
# India                                           3.407500           0.261514
# China                                           4.701981           0.334502
# United States                                  16.338498           0.335926
# Brazil                                          8.424043           0.204985
# Indonesia                                       2.922273           0.227120
# ...                                                  ...                ...
# Belize                                          4.595085           0.194571
# Barbados                                        7.016591           0.230130
# Vanuatu                                         3.639407           0.214871
# Samoa                                           5.625101           0.234937
# Sao Tome and Principe                           6.624830           0.177592
#
#                        Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# India                              0.555935              0.146703
# China                              0.322203              0.145970
# United States                      0.652297              0.525801
# Brazil                             1.106712              0.270179
# Indonesia                          0.539603              0.138858
# ...                                     ...                   ...
# Belize                             0.880364              0.255608
# Barbados                           0.919692              0.324001
# Vanuatu                            0.427027              0.105290
# Samoa                              0.460435              0.125234
# Sao Tome and Principe              0.662652              0.129756
#
#                        Anxiety disorders (%)  Drug use disorders (%)  \
# Country Name
# India                               3.292028                0.512375
# China                               3.094039                1.064983
# United States                       6.667410                3.174581
# Brazil                              6.263148                1.047308
# Indonesia                           3.274802                0.576971
# ...                                      ...                     ...
# Belize                              4.557809                0.831608
# Barbados                            4.664651                0.844089
# Vanuatu                             3.215815                0.683581
# Samoa                               3.255870                0.856471
# Sao Tome and Principe               2.918029                0.481449
#
#                        Depression (%)  Alcohol use disorders (%)  ...  \
# Country Name                                                      ...
# India                        3.519355                   1.149992  ...
# China                        3.368524                   1.229753  ...
# United States                4.786085                   2.013025  ...
# Brazil                       3.373768                   2.699771  ...
# Indonesia                    2.621234                   0.647895  ...
# ...                               ...                        ...  ...
# Belize                       2.838086                   1.766149  ...
# Barbados                     2.752176                   1.590162  ...
# Vanuatu                      3.139916                   1.209627  ...
# Samoa                        3.053512                   1.109336  ...
# Sao Tome and Principe        3.112706                   1.010334  ...
#
#                        Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# India                                                        3460.609565
# China                                                        3168.357908
# United States                                                4350.217810
# Brazil                                                       3229.418622
# Indonesia                                                    2549.945462
# ...                                                                  ...
# Belize                                                       2727.326827
# Barbados                                                     2605.323089
# Vanuatu                                                      3089.532503
# Samoa                                                        2964.920225
# Sao Tome and Principe                                        3043.673023
#
#                        GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# India                           1561.825028              6.904325e+10
# China                           7006.222991              4.570069e+11
# United States                  54348.025610              2.824040e+12
# Brazil                         11058.500273              1.867608e+11
# Indonesia                       3522.144003              2.624168e+10
# ...                                     ...                       ...
# Belize                          5837.361382              9.384594e+07
# Barbados                       17056.346071              3.314429e+08
# Vanuatu                         2859.447517              2.763240e+07
# Samoa                           3942.609898              4.468664e+07
# Sao Tome and Principe           1324.926020              1.720172e+07
#
#                        Schizophrenia (#)  Bipolar disorder (#)  \
# Country Name
# India                       3.394645e+06          7.218256e+06
# China                       4.573022e+06          4.404424e+06
# United States               1.065734e+06          2.069513e+06
# Brazil                      4.151737e+05          2.241451e+06
# Indonesia                   5.782293e+05          1.373521e+06
# ...                                  ...                   ...
# Belize                      6.780242e+02          3.067772e+03
# Barbados                    6.376469e+02          2.548320e+03
# Vanuatu                     5.740860e+02          1.140959e+03
# Samoa                       4.721048e+02          9.252363e+02
# Sao Tome and Principe       3.470517e+02          1.294825e+03
#
#                        Eating disorders (#)  Anxiety disorders (#)  \
# Country Name
# India                          1.907310e+06           4.274406e+07
# China                          1.997080e+06           4.228740e+07
# United States                  1.667848e+06           2.115255e+07
# Brazil                         5.473838e+05           1.268058e+07
# Indonesia                      3.538496e+05           8.335739e+06
# ...                                     ...                    ...
# Belize                         8.910494e+02           1.588286e+04
# Barbados                       8.977272e+02           1.292498e+04
# Vanuatu                        2.814159e+02           8.592229e+03
# Samoa                          2.516850e+02           6.542632e+03
# Sao Tome and Principe          2.538018e+02           5.701819e+03
#
#                        Drug use disorders (#)  Depression (#)  \
# Country Name
# India                            6.655644e+06    4.569380e+07
# China                            1.456321e+07    4.604112e+07
# United States                    1.008020e+07    1.518609e+07
# Brazil                           2.121516e+06    6.830304e+06
# Indonesia                        1.469086e+06    6.672680e+06
# ...                                       ...             ...
# Belize                           2.898057e+03    9.889249e+03
# Barbados                         2.338805e+03    7.625932e+03
# Vanuatu                          1.827597e+03    8.387857e+03
# Samoa                            1.720831e+03    6.135594e+03
# Sao Tome and Principe            9.414931e+02    6.082968e+03
#
#                        Alcohol use disorders (#)
# Country Name
# India                               1.492206e+07
# China                               1.681031e+07
# United States                       6.387442e+06
# Brazil                              5.467555e+06
# Indonesia                           1.649272e+06
# ...                                          ...
# Belize                              6.155853e+03
# Barbados                            4.405995e+03
# Vanuatu                             3.232364e+03
# Samoa                               2.229236e+03
# Sao Tome and Principe               1.974535e+03
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Schizophrenia (#)", ascending=False)
# Out:
#                          Year  GDP (Current USD)  \
# Country Name
# China                  2013.5       9.602800e+12
# India                  2013.5       2.034002e+12
# United States          2013.5       1.726294e+13
# Indonesia              2013.5       8.972028e+11
# Pakistan               2013.5       2.700313e+11
# ...                       ...                ...
# Belize                 2013.5       2.038282e+09
# Barbados               2013.5       4.726552e+09
# Vanuatu                2013.5       7.638936e+08
# Samoa                  2013.5       7.931049e+08
# Sao Tome and Principe  2013.5       2.600348e+08
#
#                        Percentage GDP Health Expenditure  Schizophrenia (%)  \
# Country Name
# China                                           4.701981           0.334502
# India                                           3.407500           0.261514
# United States                                  16.338498           0.335926
# Indonesia                                       2.922273           0.227120
# Pakistan                                        2.426181           0.256468
# ...                                                  ...                ...
# Belize                                          4.595085           0.194571
# Barbados                                        7.016591           0.230130
# Vanuatu                                         3.639407           0.214871
# Samoa                                           5.625101           0.234937
# Sao Tome and Principe                           6.624830           0.177592
#
#                        Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# China                              0.322203              0.145970
# India                              0.555935              0.146703
# United States                      0.652297              0.525801
# Indonesia                          0.539603              0.138858
# Pakistan                           0.573501              0.150134
# ...                                     ...                   ...
# Belize                             0.880364              0.255608
# Barbados                           0.919692              0.324001
# Vanuatu                            0.427027              0.105290
# Samoa                              0.460435              0.125234
# Sao Tome and Principe              0.662652              0.129756
#
#                        Anxiety disorders (%)  Drug use disorders (%)  \
# Country Name
# China                               3.094039                1.064983
# India                               3.292028                0.512375
# United States                       6.667410                3.174581
# Indonesia                           3.274802                0.576971
# Pakistan                            3.816029                0.673662
# ...                                      ...                     ...
# Belize                              4.557809                0.831608
# Barbados                            4.664651                0.844089
# Vanuatu                             3.215815                0.683581
# Samoa                               3.255870                0.856471
# Sao Tome and Principe               2.918029                0.481449
#
#                        Depression (%)  Alcohol use disorders (%)  ...  \
# Country Name                                                      ...
# China                        3.368524                   1.229753  ...
# India                        3.519355                   1.149992  ...
# United States                4.786085                   2.013025  ...
# Indonesia                    2.621234                   0.647895  ...
# Pakistan                     3.310687                   1.516488  ...
# ...                               ...                        ...  ...
# Belize                       2.838086                   1.766149  ...
# Barbados                     2.752176                   1.590162  ...
# Vanuatu                      3.139916                   1.209627  ...
# Samoa                        3.053512                   1.109336  ...
# Sao Tome and Principe        3.112706                   1.010334  ...
#
#                        Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# China                                                        3168.357908
# India                                                        3460.609565
# United States                                                4350.217810
# Indonesia                                                    2549.945462
# Pakistan                                                     3218.450761
# ...                                                                  ...
# Belize                                                       2727.326827
# Barbados                                                     2605.323089
# Vanuatu                                                      3089.532503
# Samoa                                                        2964.920225
# Sao Tome and Principe                                        3043.673023
#
#                        GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# China                           7006.222991              4.570069e+11
# India                           1561.825028              6.904325e+10
# United States                  54348.025610              2.824040e+12
# Indonesia                       3522.144003              2.624168e+10
# Pakistan                        1303.835747              6.614426e+09
# ...                                     ...                       ...
# Belize                          5837.361382              9.384594e+07
# Barbados                       17056.346071              3.314429e+08
# Vanuatu                         2859.447517              2.763240e+07
# Samoa                           3942.609898              4.468664e+07
# Sao Tome and Principe           1324.926020              1.720172e+07
#
#                        Schizophrenia (#)  Bipolar disorder (#)  \
# Country Name
# China                       4.573022e+06          4.404424e+06
# India                       3.394645e+06          7.218256e+06
# United States               1.065734e+06          2.069513e+06
# Indonesia                   5.782293e+05          1.373521e+06
# Pakistan                    5.288820e+05          1.182689e+06
# ...                                  ...                   ...
# Belize                      6.780242e+02          3.067772e+03
# Barbados                    6.376469e+02          2.548320e+03
# Vanuatu                     5.740860e+02          1.140959e+03
# Samoa                       4.721048e+02          9.252363e+02
# Sao Tome and Principe       3.470517e+02          1.294825e+03
#
#                        Eating disorders (#)  Anxiety disorders (#)  \
# Country Name
# China                          1.997080e+06           4.228740e+07
# India                          1.907310e+06           4.274406e+07
# United States                  1.667848e+06           2.115255e+07
# Indonesia                      3.538496e+05           8.335739e+06
# Pakistan                       3.098181e+05           7.869688e+06
# ...                                     ...                    ...
# Belize                         8.910494e+02           1.588286e+04
# Barbados                       8.977272e+02           1.292498e+04
# Vanuatu                        2.814159e+02           8.592229e+03
# Samoa                          2.516850e+02           6.542632e+03
# Sao Tome and Principe          2.538018e+02           5.701819e+03
#
#                        Drug use disorders (#)  Depression (#)  \
# Country Name
# China                            1.456321e+07    4.604112e+07
# India                            6.655644e+06    4.569380e+07
# United States                    1.008020e+07    1.518609e+07
# Indonesia                        1.469086e+06    6.672680e+06
# Pakistan                         1.388571e+06    6.827566e+06
# ...                                       ...             ...
# Belize                           2.898057e+03    9.889249e+03
# Barbados                         2.338805e+03    7.625932e+03
# Vanuatu                          1.827597e+03    8.387857e+03
# Samoa                            1.720831e+03    6.135594e+03
# Sao Tome and Principe            9.414931e+02    6.082968e+03
#
#                        Alcohol use disorders (#)
# Country Name
# China                               1.681031e+07
# India                               1.492206e+07
# United States                       6.387442e+06
# Indonesia                           1.649272e+06
# Pakistan                            3.128077e+06
# ...                                          ...
# Belize                              6.155853e+03
# Barbados                            4.405995e+03
# Vanuatu                             3.232364e+03
# Samoa                               2.229236e+03
# Sao Tome and Principe               1.974535e+03
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Bipolar disorder (#)", ascending=False)
# Out:
#                          Year  GDP (Current USD)  \
# Country Name
# India                  2013.5       2.034002e+12
# China                  2013.5       9.602800e+12
# Brazil                 2013.5       2.235063e+12
# United States          2013.5       1.726294e+13
# Indonesia              2013.5       8.972028e+11
# ...                       ...                ...
# Barbados               2013.5       4.726552e+09
# Solomon Islands        2013.5       1.240740e+09
# Sao Tome and Principe  2013.5       2.600348e+08
# Vanuatu                2013.5       7.638936e+08
# Samoa                  2013.5       7.931049e+08
#
#                        Percentage GDP Health Expenditure  Schizophrenia (%)  \
# Country Name
# India                                           3.407500           0.261514
# China                                           4.701981           0.334502
# Brazil                                          8.424043           0.204985
# United States                                  16.338498           0.335926
# Indonesia                                       2.922273           0.227120
# ...                                                  ...                ...
# Barbados                                        7.016591           0.230130
# Solomon Islands                                 4.628046           0.209428
# Sao Tome and Principe                           6.624830           0.177592
# Vanuatu                                         3.639407           0.214871
# Samoa                                           5.625101           0.234937
#
#                        Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# India                              0.555935              0.146703
# China                              0.322203              0.145970
# Brazil                             1.106712              0.270179
# United States                      0.652297              0.525801
# Indonesia                          0.539603              0.138858
# ...                                     ...                   ...
# Barbados                           0.919692              0.324001
# Solomon Islands                    0.427262              0.091229
# Sao Tome and Principe              0.662652              0.129756
# Vanuatu                            0.427027              0.105290
# Samoa                              0.460435              0.125234
#
#                        Anxiety disorders (%)  Drug use disorders (%)  \
# Country Name
# India                               3.292028                0.512375
# China                               3.094039                1.064983
# Brazil                              6.263148                1.047308
# United States                       6.667410                3.174581
# Indonesia                           3.274802                0.576971
# ...                                      ...                     ...
# Barbados                            4.664651                0.844089
# Solomon Islands                     3.207645                0.691640
# Sao Tome and Principe               2.918029                0.481449
# Vanuatu                             3.215815                0.683581
# Samoa                               3.255870                0.856471
#
#                        Depression (%)  Alcohol use disorders (%)  ...  \
# Country Name                                                      ...
# India                        3.519355                   1.149992  ...
# China                        3.368524                   1.229753  ...
# Brazil                       3.373768                   2.699771  ...
# United States                4.786085                   2.013025  ...
# Indonesia                    2.621234                   0.647895  ...
# ...                               ...                        ...  ...
# Barbados                     2.752176                   1.590162  ...
# Solomon Islands              3.169442                   1.136224  ...
# Sao Tome and Principe        3.112706                   1.010334  ...
# Vanuatu                      3.139916                   1.209627  ...
# Samoa                        3.053512                   1.109336  ...
#
#                        Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# India                                                        3460.609565
# China                                                        3168.357908
# Brazil                                                       3229.418622
# United States                                                4350.217810
# Indonesia                                                    2549.945462
# ...                                                                  ...
# Barbados                                                     2605.323089
# Solomon Islands                                              3122.976771
# Sao Tome and Principe                                        3043.673023
# Vanuatu                                                      3089.532503
# Samoa                                                        2964.920225
#
#                        GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# India                           1561.825028              6.904325e+10
# China                           7006.222991              4.570069e+11
# Brazil                         11058.500273              1.867608e+11
# United States                  54348.025610              2.824040e+12
# Indonesia                       3522.144003              2.624168e+10
# ...                                     ...                       ...
# Barbados                       17056.346071              3.314429e+08
# Solomon Islands                 2091.169934              5.713998e+07
# Sao Tome and Principe           1324.926020              1.720172e+07
# Vanuatu                         2859.447517              2.763240e+07
# Samoa                           3942.609898              4.468664e+07
#
#                        Schizophrenia (#)  Bipolar disorder (#)  \
# Country Name
# India                       3.394645e+06          7.218256e+06
# China                       4.573022e+06          4.404424e+06
# Brazil                      4.151737e+05          2.241451e+06
# United States               1.065734e+06          2.069513e+06
# Indonesia                   5.782293e+05          1.373521e+06
# ...                                  ...                   ...
# Barbados                    6.376469e+02          2.548320e+03
# Solomon Islands             1.237408e+03          2.524147e+03
# Sao Tome and Principe       3.470517e+02          1.294825e+03
# Vanuatu                     5.740860e+02          1.140959e+03
# Samoa                       4.721048e+02          9.252363e+02
#
#                        Eating disorders (#)  Anxiety disorders (#)  \
# Country Name
# India                          1.907310e+06           4.274406e+07
# China                          1.997080e+06           4.228740e+07
# Brazil                         5.473838e+05           1.268058e+07
# United States                  1.667848e+06           2.115255e+07
# Indonesia                      3.538496e+05           8.335739e+06
# ...                                     ...                    ...
# Barbados                       8.977272e+02           1.292498e+04
# Solomon Islands                5.395427e+02           1.895079e+04
# Sao Tome and Principe          2.538018e+02           5.701819e+03
# Vanuatu                        2.814159e+02           8.592229e+03
# Samoa                          2.516850e+02           6.542632e+03
#
#                        Drug use disorders (#)  Depression (#)  \
# Country Name
# India                            6.655644e+06    4.569380e+07
# China                            1.456321e+07    4.604112e+07
# Brazil                           2.121516e+06    6.830304e+06
# United States                    1.008020e+07    1.518609e+07
# Indonesia                        1.469086e+06    6.672680e+06
# ...                                       ...             ...
# Barbados                         2.338805e+03    7.625932e+03
# Solomon Islands                  4.088198e+03    1.872063e+04
# Sao Tome and Principe            9.414931e+02    6.082968e+03
# Vanuatu                          1.827597e+03    8.387857e+03
# Samoa                            1.720831e+03    6.135594e+03
#
#                        Alcohol use disorders (#)
# Country Name
# India                               1.492206e+07
# China                               1.681031e+07
# Brazil                              5.467555e+06
# United States                       6.387442e+06
# Indonesia                           1.649272e+06
# ...                                          ...
# Barbados                            4.405995e+03
# Solomon Islands                     6.712200e+03
# Sao Tome and Principe               1.974535e+03
# Vanuatu                             3.232364e+03
# Samoa                               2.229236e+03
#
# [140 rows x 31 columns]

# %%
Macro_Disorder_ext_df.drop("Country Code", axis=1).groupby("Country Name").mean().sort_values("Eating disorders (#)", ascending=False)
# Out:
#                          Year  GDP (Current USD)  \
# Country Name
# China                  2013.5       9.602800e+12
# India                  2013.5       2.034002e+12
# United States          2013.5       1.726294e+13
# Japan                  2013.5       5.344169e+12
# Brazil                 2013.5       2.235063e+12
# ...                       ...                ...
# Comoros                2013.5       1.033628e+09
# Solomon Islands        2013.5       1.240740e+09
# Vanuatu                2013.5       7.638936e+08
# Sao Tome and Principe  2013.5       2.600348e+08
# Samoa                  2013.5       7.931049e+08
#
#                        Percentage GDP Health Expenditure  Schizophrenia (%)  \
# Country Name
# China                                           4.701981           0.334502
# India                                           3.407500           0.261514
# United States                                  16.338498           0.335926
# Japan                                          10.461250           0.301147
# Brazil                                          8.424043           0.204985
# ...                                                  ...                ...
# Comoros                                         5.041323           0.169668
# Solomon Islands                                 4.628046           0.209428
# Vanuatu                                         3.639407           0.214871
# Sao Tome and Principe                           6.624830           0.177592
# Samoa                                           5.625101           0.234937
#
#                        Bipolar disorder (%)  Eating disorders (%)  \
# Country Name
# China                              0.322203              0.145970
# India                              0.555935              0.146703
# United States                      0.652297              0.525801
# Japan                              0.688160              0.458133
# Brazil                             1.106712              0.270179
# ...                                     ...                   ...
# Comoros                            0.657060              0.110264
# Solomon Islands                    0.427262              0.091229
# Vanuatu                            0.427027              0.105290
# Sao Tome and Principe              0.662652              0.129756
# Samoa                              0.460435              0.125234
#
#                        Anxiety disorders (%)  Drug use disorders (%)  \
# Country Name
# China                               3.094039                1.064983
# India                               3.292028                0.512375
# United States                       6.667410                3.174581
# Japan                               3.560696                0.898137
# Brazil                              6.263148                1.047308
# ...                                      ...                     ...
# Comoros                             3.622229                0.497505
# Solomon Islands                     3.207645                0.691640
# Vanuatu                             3.215815                0.683581
# Sao Tome and Principe               2.918029                0.481449
# Samoa                               3.255870                0.856471
#
#                        Depression (%)  Alcohol use disorders (%)  ...  \
# Country Name                                                      ...
# China                        3.368524                   1.229753  ...
# India                        3.519355                   1.149992  ...
# United States                4.786085                   2.013025  ...
# Japan                        3.221601                   0.573446  ...
# Brazil                       3.373768                   2.699771  ...
# ...                               ...                        ...  ...
# Comoros                      3.295844                   1.507672  ...
# Solomon Islands              3.169442                   1.136224  ...
# Vanuatu                      3.139916                   1.209627  ...
# Sao Tome and Principe        3.112706                   1.010334  ...
# Samoa                        3.053512                   1.109336  ...
#
#                        Depressive disorder rates (number suffering per 100,000)  \
# Country Name
# China                                                        3168.357908
# India                                                        3460.609565
# United States                                                4350.217810
# Japan                                                        2898.432240
# Brazil                                                       3229.418622
# ...                                                                  ...
# Comoros                                                      3209.544792
# Solomon Islands                                              3122.976771
# Vanuatu                                                      3089.532503
# Sao Tome and Principe                                        3043.673023
# Samoa                                                        2964.920225
#
#                        GDP per Capita (USD)  Health Expenditure (USD)  \
# Country Name
# China                           7006.222991              4.570069e+11
# India                           1561.825028              6.904325e+10
# United States                  54348.025610              2.824040e+12
# Japan                          41927.215530              5.579178e+11
# Brazil                         11058.500273              1.867608e+11
# ...                                     ...                       ...
# Comoros                         1461.789359              5.220461e+07
# Solomon Islands                 2091.169934              5.713998e+07
# Vanuatu                         2859.447517              2.763240e+07
# Sao Tome and Principe           1324.926020              1.720172e+07
# Samoa                           3942.609898              4.468664e+07
#
#                        Schizophrenia (#)  Bipolar disorder (#)  \
# Country Name
# China                       4.573022e+06          4.404424e+06
# India                       3.394645e+06          7.218256e+06
# United States               1.065734e+06          2.069513e+06
# Japan                       3.837610e+05          8.769237e+05
# Brazil                      4.151737e+05          2.241451e+06
# ...                                  ...                   ...
# Comoros                     1.201093e+03          4.651438e+03
# Solomon Islands             1.237408e+03          2.524147e+03
# Vanuatu                     5.740860e+02          1.140959e+03
# Sao Tome and Principe       3.470517e+02          1.294825e+03
# Samoa                       4.721048e+02          9.252363e+02
#
#                        Eating disorders (#)  Anxiety disorders (#)  \
# Country Name
# China                          1.997080e+06           4.228740e+07
# India                          1.907310e+06           4.274406e+07
# United States                  1.667848e+06           2.115255e+07
# Japan                          5.838062e+05           4.537384e+06
# Brazil                         5.473838e+05           1.268058e+07
# ...                                     ...                    ...
# Comoros                        7.806128e+02           2.564500e+04
# Solomon Islands                5.395427e+02           1.895079e+04
# Vanuatu                        2.814159e+02           8.592229e+03
# Sao Tome and Principe          2.538018e+02           5.701819e+03
# Samoa                          2.516850e+02           6.542632e+03
#
#                        Drug use disorders (#)  Depression (#)  \
# Country Name
# China                            1.456321e+07    4.604112e+07
# India                            6.655644e+06    4.569380e+07
# United States                    1.008020e+07    1.518609e+07
# Japan                            1.144454e+06    4.105050e+06
# Brazil                           2.121516e+06    6.830304e+06
# ...                                       ...             ...
# Comoros                          3.523153e+03    2.333560e+04
# Solomon Islands                  4.088198e+03    1.872063e+04
# Vanuatu                          1.827597e+03    8.387857e+03
# Sao Tome and Principe            9.414931e+02    6.082968e+03
# Samoa                            1.720831e+03    6.135594e+03
#
#                        Alcohol use disorders (#)
# Country Name
# China                               1.681031e+07
# India                               1.492206e+07
# United States                       6.387442e+06
# Japan                               7.307240e+05
# Brazil                              5.467555e+06
# ...                                          ...
# Comoros                             1.067268e+04
# Solomon Islands                     6.712200e+03
# Vanuatu                             3.232364e+03
# Sao Tome and Principe               1.974535e+03
# Samoa                               2.229236e+03
#
# [140 rows x 31 columns]

# %% [markdown]
# ### Pivot Data

# %%
Depression_Numbers_by_Country = Macro_Disorder_ext_df[['Country Name', 'Year', 'Depression (#)']]

Depression_Numbers_by_Country
# Out:
#               Country Name  Year  Depression (#)
# 0              Afghanistan  2010    1.164480e+06
# 1                   Angola  2010    9.708281e+05
# 2                  Albania  2010    6.418382e+04
# 3     United Arab Emirates  2010    2.426556e+05
# 4                Argentina  2010    1.487934e+06
# ...                    ...   ...             ...
# 1105               Vanuatu  2017    9.063279e+03
# 1106                 Samoa  2017    6.309747e+03
# 1107          South Africa  2017    2.121707e+06
# 1108                Zambia  2017    6.299624e+05
# 1109              Zimbabwe  2017    4.709715e+05
#
# [1110 rows x 3 columns]

# %%
Depression_pivot_df = Depression_Numbers_by_Country.pivot(index="Year", columns="Country Name", values="Depression (#)")

Depression_pivot_df
# Out:
# Country Name   Afghanistan       Albania       Algeria        Angola  \
# Year
# 2010          1.164480e+06  64183.815162  1.295543e+06  9.708281e+05
# 2011          1.208242e+06  63980.848017  1.321112e+06  1.008068e+06
# 2012          1.259023e+06  63872.398790  1.347567e+06  1.046702e+06
# 2013          1.304122e+06  63781.713950  1.376560e+06  1.087280e+06
# 2014          1.352333e+06  63666.722591  1.406796e+06  1.127581e+06
# 2015          1.395849e+06  63503.772512  1.438169e+06  1.169687e+06
# 2016          1.432448e+06  63461.369892  1.471505e+06  1.212208e+06
# 2017          1.474335e+06  63457.826672  1.506048e+06  1.256825e+06
#
# Country Name     Argentina       Armenia     Australia        Austria  \
# Year
# 2010          1.487934e+06  79967.665884  1.065063e+06  275173.303846
# 2011          1.505012e+06  79612.291628  1.075364e+06  275657.500489
# 2012          1.522590e+06  79325.876546  1.088951e+06  276382.650129
# 2013          1.540848e+06  79110.062839  1.100826e+06  277593.620167
# 2014          1.559219e+06  79016.263765  1.110668e+06  279248.763758
# 2015          1.577631e+06  78881.822140  1.118583e+06  282100.461024
# 2016          1.595979e+06  78733.514830  1.127252e+06  285043.491201
# 2017          1.614457e+06  78558.586131  1.137132e+06  286885.987990
#
# Country Name     Azerbaijan    Bangladesh  ...        Uganda       Ukraine  \
# Year                                       ...
# 2010          230198.423288  6.268991e+06  ...  1.676925e+06  1.911427e+06
# 2011          233651.057393  6.340958e+06  ...  1.714011e+06  1.896303e+06
# 2012          237188.249893  6.408601e+06  ...  1.751474e+06  1.883657e+06
# 2013          240872.258611  6.467884e+06  ...  1.789051e+06  1.872000e+06
# 2014          244343.169281  6.522946e+06  ...  1.829711e+06  1.856356e+06
# 2015          248106.364621  6.567106e+06  ...  1.872370e+06  1.847429e+06
# 2016          251844.346392  6.610165e+06  ...  1.920758e+06  1.837606e+06
# 2017          255445.407677  6.650720e+06  ...  1.973461e+06  1.827506e+06
#
# Country Name  United Arab Emirates  United Kingdom  United States  \
# Year
# 2010                 242655.580263    2.590247e+06   1.472877e+07
# 2011                 245006.212401    2.610204e+06   1.483861e+07
# 2012                 247275.079793    2.628345e+06   1.495778e+07
# 2013                 249632.520238    2.645820e+06   1.508371e+07
# 2014                 252228.583180    2.665049e+06   1.522594e+07
# 2015                 255007.706827    2.685676e+06   1.538249e+07
# 2016                 258011.317213    2.704828e+06   1.554981e+07
# 2017                 260933.506861    2.721311e+06   1.572164e+07
#
# Country Name        Uruguay     Uzbekistan      Vanuatu         Zambia  \
# Year
# 2010          118101.355815  824196.328776  7729.334606  482310.074945
# 2011          118702.125396  846355.432164  7911.727731  499430.313086
# 2012          119429.937863  858847.238970  8099.001296  517965.533222
# 2013          120231.176749  871856.110944  8288.990244  537786.578263
# 2014          121087.760059  887151.722948  8478.299099  559070.774933
# 2015          121997.252457  902690.948922  8667.119148  581135.494038
# 2016          122905.919711  919085.806940  8865.105744  605122.169105
# 2017          123800.617428  935034.266664  9063.278741  629962.433358
#
# Country Name       Zimbabwe
# Year
# 2010          398733.824099
# 2011          405040.171279
# 2012          413622.571618
# 2013          424039.626570
# 2014          435110.825884
# 2015          446688.762403
# 2016          458748.191583
# 2017          470971.530107
#
# [8 rows x 140 columns]

# %% [markdown]
# ### Depression by Country Line Plot

# %%
plt.figure(figsize=(14, 8))
for country in Depression_pivot_df.columns:
    plt.plot(Depression_pivot_df.index, Depression_pivot_df[country], marker='o', label=country)

plt.title('Depression Rate by Country Over Years')
plt.xlabel('Year')
plt.ylabel('Depression Rate (%)')
plt.xticks(Depression_pivot_df.index)
plt.legend(title='Country Name')
plt.grid()
plt.show()

# %% [markdown]
# ### Health Expenditure Scatters

# %%
HealthExp_Drugs = Macro_Disorder_df[['Country Name', 'Percentage GDP Health Expenditure', 'Drug use disorders (%)']]
HealthExp_Drugs = HealthExp_Drugs.groupby("Country Name").mean()
HealthExp_Drugs.plot(kind="scatter", x = "Percentage GDP Health Expenditure", y = "Drug use disorders (%)")
# Out:
# <Axes: xlabel='Percentage GDP Health Expenditure', ylabel='Drug use disorders (%)'>

# %%
HealthExp_Depression = Macro_Disorder_df[['Country Name', 'Percentage GDP Health Expenditure', 'Depression (%)']]
HealthExp_Depression = HealthExp_Depression.groupby("Country Name").mean()
HealthExp_Depression.plot(kind="scatter", x = "Percentage GDP Health Expenditure", y = "Depression (%)")
# Out:
# <Axes: xlabel='Percentage GDP Health Expenditure', ylabel='Depression (%)'>

# %%
HealthExp_Eat = Macro_Disorder_df[['Country Name', 'Percentage GDP Health Expenditure', 'Eating disorders (%)']]
HealthExp_Eat = HealthExp_Eat.groupby("Country Name").mean()
HealthExp_Eat.plot(kind="scatter", x = "Percentage GDP Health Expenditure", y = "Eating disorders (%)")
# Out:
# <Axes: xlabel='Percentage GDP Health Expenditure', ylabel='Eating disorders (%)'>

# %% [markdown]
# ### Unknown

# %%
Macro_Disorder_ext_df.loc[Macro_Disorder_ext_df['Year'] == 2010]
# Out:
#              Country Name Country Code  Year  GDP (Current USD)  \
# 0             Afghanistan          AFG  2010       1.585667e+10
# 1                  Angola          AGO  2010       8.379947e+10
# 2                 Albania          ALB  2010       1.192693e+10
# 3    United Arab Emirates          ARE  2010       3.001891e+11
# 4               Argentina          ARG  2010       4.236274e+11
# ..                    ...          ...   ...                ...
# 133               Vanuatu          VUT  2010       6.707130e+08
# 134                 Samoa          WSM  2010       6.802609e+08
# 135          South Africa          ZAF  2010       4.173638e+11
# 136                Zambia          ZMB  2010       2.026556e+10
# 137              Zimbabwe          ZWE  2010       1.204166e+10
#
#      Percentage GDP Health Expenditure  Schizophrenia (%)  \
# 0                             8.569672           0.165130
# 1                             2.695100           0.170158
# 2                             6.236677           0.199308
# 3                             3.878731           0.213138
# 4                             9.445464           0.197541
# ..                                 ...                ...
# 133                           3.526561           0.214731
# 134                           5.152683           0.234772
# 135                           7.793582           0.180770
# 136                           3.974719           0.162712
# 137                          10.475839           0.155312
#
#      Bipolar disorder (%)  Eating disorders (%)  Anxiety disorders (%)  \
# 0                0.705313              0.097327               4.862777
# 1                0.622503              0.156364               3.277828
# 2                0.703064              0.160337               3.391246
# 3                0.801470              0.260129               4.200126
# 4                0.771084              0.381185               6.268718
# ..                    ...                   ...                    ...
# 133              0.426569              0.104303               3.212105
# 134              0.460375              0.123989               3.255222
# 135              0.635103              0.210795               3.995125
# 136              0.603678              0.129023               3.562279
# 137              0.606897              0.116347               3.083865
#
#      Drug use disorders (%)  ...  \
# 0                  2.571349  ...
# 1                  0.503415  ...
# 2                  0.500270  ...
# 3                  3.059998  ...
# 4                  0.955035  ...
# ..                      ...  ...
# 133                0.673466  ...
# 134                0.861347  ...
# 135                1.042054  ...
# 136                0.495711  ...
# 137                0.756577  ...
#
#      Depressive disorder rates (number suffering per 100,000)  \
# 0                                          4053.953769
# 1                                          4098.150892
# 2                                          2106.380192
# 3                                          2711.270791
# 4                                          3363.831257
# ..                                                 ...
# 133                                        3101.896817
# 134                                        2977.817804
# 135                                        3578.643830
# 136                                        3449.247356
# 137                                        3031.304268
#
#      GDP per Capita (USD)  Health Expenditure (USD)  Schizophrenia (#)  \
# 0              562.499222              1.358864e+09       46549.605374
# 1             3586.663694              2.258479e+09       39756.029912
# 2             4094.349686              7.438439e+08        5805.883895
# 3            35392.260966              1.164352e+10       18077.877074
# 4            10385.964432              4.001358e+10       80573.917941
# ..                    ...                       ...                ...
# 133           2732.551568              2.365310e+07         527.063681
# 134           3494.395224              3.505169e+07         457.035348
# 135           8059.562798              3.252759e+10       93611.601692
# 136           1469.361450              8.054991e+08       22441.378972
# 137            937.840340              1.261464e+09       19941.705136
#
#      Bipolar disorder (#)  Eating disorders (#)  Anxiety disorders (#)  \
# 0           198825.421273          27436.162067           1.370801e+06
# 1           145442.752551          36533.174233           7.658378e+05
# 2            20480.401963           4670.650481           9.878771e+04
# 3            67978.850034          22063.546085           3.562451e+05
# 4           314513.234931         155479.464568           2.556913e+06
# ..                    ...                   ...                    ...
# 133           1047.026408            256.014843           7.884208e+03
# 134            896.221220            241.371866           6.337006e+03
# 135         328887.586819         109160.024222           2.068872e+06
# 136          83259.788923          17794.963120           4.913126e+05
# 137          77924.185006          14938.688365           3.959612e+05
#
#      Drug use disorders (#)  Depression (#)  Alcohol use disorders (#)
# 0             724854.849075    1.164480e+06              186633.106237
# 1             117618.811918    9.708281e+05              324339.980677
# 2              14572.970157    6.418382e+04               53557.813679
# 3             259542.022965    2.426556e+05               65206.328729
# 4             389544.002109    1.487934e+06              750168.175271
# ..                      ...             ...                        ...
# 133             1653.042501    7.729335e+03                2953.791220
# 134             1676.801432    5.969208e+03                2153.874369
# 135           539626.840677    1.916016e+06              861483.070923
# 136            68368.887431    4.823101e+05              224918.993833
# 137            97142.754239    3.987338e+05              194516.239162
#
# [138 rows x 33 columns]
