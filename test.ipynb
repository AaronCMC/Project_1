# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
Mental_Health = Path("Resources/Mental Health Dataset.csv")
Mental_Health_df = pd.read_csv(Mental_Health)

Mental_Disorders = Path("Resources/Mental health Depression disorder Data.csv")
Mental_Disorders_df = pd.read_csv(Mental_Disorders, delimiter=',', encoding = 'utf-8')

World_Bank = Path("Resources/2.12_Health_systems.csv")
World_Bank_df = pd.read_csv(World_Bank)
# Out:
# /var/folders/m6/bhhzzj012vq18r_pf4rv2l640000gn/T/ipykernel_2925/4113992705.py:5: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   Mental_Disorders_df = pd.read_csv(Mental_Disorders, delimiter=',', encoding = 'utf-8')

# %%
Mental_Health_df["Occupation"].unique()
# Out:
# array(['Corporate', 'Student', 'Business', 'Housewife', 'Others'],
#       dtype=object)

# %%
Mental_Health_df.head()
# Out:
#          Timestamp  Gender        Country Occupation self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate           NaN
# 1  8/27/2014 11:31  Female  United States  Corporate           NaN
# 2  8/27/2014 11:32  Female  United States  Corporate           NaN
# 3  8/27/2014 11:37  Female  United States  Corporate            No
# 4  8/27/2014 11:43  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# ...

# %%
Mental_Health_df.tail()
# Out:
#               Timestamp Gender        Country Occupation self_employed  \
# 292359  7/27/2015 23:25   Male  United States   Business           Yes
# 292360   8/17/2015 9:38   Male   South Africa   Business            No
# 292361  8/25/2015 19:59   Male  United States   Business            No
# 292362   9/26/2015 1:07   Male  United States   Business            No
# 292363   2/1/2016 23:04   Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 292359            Yes       Yes   15-30 days             No          Maybe
# 292360            Yes       Yes   15-30 days             No          Maybe
# 292361            Yes        No   15-30 days             No          Maybe
# 292362            Yes       Yes   15-30 days             No          Maybe
# 292363            Yes       Yes   15-30 days             No          Maybe
#
#        Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# ...

# %%
Mental_Disorders_df.head(500)
# Out:
#      index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0        0  Afghanistan  AFG  1990           0.16056             0.697779
# 1        1  Afghanistan  AFG  1991          0.160312             0.697961
# 2        2  Afghanistan  AFG  1992          0.160135             0.698107
# 3        3  Afghanistan  AFG  1993          0.160037             0.698257
# 4        4  Afghanistan  AFG  1994          0.160022             0.698469
# ..     ...          ...  ...   ...               ...                  ...
# 495    495     Barbados  BRB  2009          0.230546              0.91946
# 496    496     Barbados  BRB  2010          0.230576             0.919504
# 497    497     Barbados  BRB  2011          0.230531             0.919525
# 498    498     Barbados  BRB  2012          0.230445             0.919566
# 499    499     Barbados  BRB  2013          0.230321             0.919632
#
#     Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# ...

# %%
Mental_Disorders_df.tail()
# Out:
#          index    Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 108548  108548  Zimbabwe  ZWE  2013      303564.60359                  NaN
# 108549  108549  Zimbabwe  ZWE  2014     311665.769283                  NaN
# 108550  108550  Zimbabwe  ZWE  2015     320638.507158                  NaN
# 108551  108551  Zimbabwe  ZWE  2016     330437.353798                  NaN
# 108552  108552  Zimbabwe  ZWE  2017     340583.157405                  NaN
#
#        Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 108548                  NaN                    NaN                     NaN
# 108549                  NaN                    NaN                     NaN
# 108550                  NaN                    NaN                     NaN
# 108551                  NaN                    NaN                     NaN
# 108552                  NaN                    NaN                     NaN
#
#         Depression (%)  Alcohol use disorders (%)
# ...

# %%
World_Bank_df.head()
# Out:
#   Country_Region Province_State World_Bank_Name  Health_exp_pct_GDP_2016  \
# 0    Afghanistan            NaN     Afghanistan                     10.2
# 1        Albania            NaN         Albania                      6.7
# 2        Algeria            NaN         Algeria                      6.6
# 3        Andorra            NaN         Andorra                     10.4
# 4         Angola            NaN          Angola                      2.9
#
#    Health_exp_public_pct_2016  Health_exp_out_of_pocket_pct_2016  \
# 0                         5.1                               77.4
# 1                        41.4                               58.0
# 2                        67.7                               30.9
# 3                        49.1                               41.7
# 4                        44.1                               35.2
#
#    Health_exp_per_capita_USD_2016  per_capita_exp_PPP_2016  \
# 0                            57.2                    162.8
# ...
